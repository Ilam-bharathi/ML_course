# %% [markdown]
# ## CS4305TU Applied Machine Learning. Week 8 Assignment (Recurrent Neural Networks)
#
# ### Short-term Drinking Water Demand Forecasting with Deep Learning Techniques
#
#
# Welcome to the assignment for Week 8 of your Applied Machine Learning course. In this assigment, you will be tasked with _forecasting drinking water demands (up to 24 hours ahead) in urban areas_ using Deep Learning techniques.
#
# <u> Background </u>
#
# Water Distribution Systems (WDS) are networked infrastructures designed to provide drinking water to citizens and businesses. Like other critical infrastructure, modern WDS rely on digitalisation to optimize their operations in order to maximise efficiency by ensuring sustainable water management practices.
#
# Digitalisation allows gathering and analysing sensor data to inform control strategies. For instance, accurate forecasting of _drinking water demands_ over shor-time horizons (e.g., 24 hours) can be used to better manage the operations of the pumping stations of the WDS, as well as optimizing the production of drinking water from water treatment plants.
#
# Water demand time series are usually recorded by flow meters located at the inlet of a district. This data can then be used to develop forecasting methods, which are usually based on time series analysis techniques or, more recently, machine learning (ML). Typical input data for these models are past water demands, meteorological data, and calendar information (e.g., day of the week, holidays, important events, ...).
#
#
# <br/>
#
#
#
#
# <center><figure>
#   <img src="https://ars.els-cdn.com/content/image/1-s2.0-S0377042716300565-gr6_lrg.jpg" width=600/>
# <figcaption>Figure 1. Water demand forecasting: observed data vs machine learning prediction.
#
# <sub><sup>Image credits: Brentan et al. (2017), https://doi.org/10.1016/j.wroa.2019.100028 </sup></sub></figcaption>
# </figure></center>
#
# <u> Problem defintion </u>
#
# The data for this assignment was kindly provided by the authors of [1]. The data refers to hourly measurments from a real WDS serving around 120k users (residential and industrial) of a medium-sized city of Northern Italy.
#
# The data spans two years. You will be using the data in "Year #1" to _train_ and _validate_ different Deep Learning (DL) models based on Feed Forward Neural Networks and Recurrent Neural Networks. The performance of these models will then be evaluated on "Year #2", the _test_ dataset. Available data includes hourly average water demand in [L/s] (liters per second). Other calendar information or meteorological data is not found to provide substantial gains in predictive performances.
#
# <b> Your goal is to build autoregressive Deep Learning models that forecast hourly water demand for the next 24 hours </b> (e.g., 24 outputs) using as input 1 week (e.g., 168 hours) of past water demand and calendar information (e.g., the _day_ boolean variable)
#
# <u> References </u>
#
# [1] Pacchin, E., Gagliardi, F., Alvisi, S. and Franchini, M., 2019. A comparison of short-term water demand forecasting models. Water resources management, 33(4), pp.1481-1497.

# %% [markdown]
# ### Part 0. Exploratory data analysis

# %% [markdown]
# #### Link to Google Drive and Load python modules

# %%
# link to Google Drive to access files
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# !ls gdrive

# %%
# install tensorflow addons (hint: it has a method to stop training after a certain time has passed)
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.14.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.4 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.14.0

# %%
# generic modules
import datetime, os
import itertools
import time

# append working folder
import sys
#working_folder = 'PLEASE INSERT HERE YOUR WORKING FOLDER'
#sys.path.append(working_folder)

# basic data science modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# keras
from tensorflow.keras.layers import Input, Dense, SimpleRNN, GRU, LSTM, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
import tensorflow_addons as tfa

# sklearn helper functions
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# import additional helper scripts 
# (note: the file assignment_utils.py should be in the working_folder specified earlier in this cell)
import assignment_utils

# %% [markdown]
# #### Exploratory data analysis

# %%
# load water demand data
df_year1 = pd.read_csv('water_demand_Y1.txt',header=None, sep=r"\s+")
df_year2 = pd.read_csv('water_demand_Y2.txt',header=None, sep=r"\s+")

# %% [markdown]
# Let's visualize the typical pattern of a random day in our data. In general, these patterns show two peaks of consumption: in the morning and in the evening. Consumption is at its lowest during late night and early mornings.

# %%
# plot random day
day_ix = np.random.randint(len(df_year1))
ax = df_year1.loc[day_ix].plot()
ax.set_xlabel('Hour of the  day');
ax.set_ylabel('Average hourly demand [L/s]');
ax.set_title(f'Water consumption for day #{day_ix} of Year #1');

# %% [markdown]
# We can obtain more information on the hour-by-hour distribution of the water demand by using boxplots. These are computed across all days for each hour of the day. By plotting the distribution for both years we see that <u> consumptions increased in Year #2 </u>. This also emerges from the overall average (red line).

# %%
# plot hourly water demand distributions across all days

# year 1
f, axes = plt.subplots(1,2,figsize=(20,6))
df_year1.boxplot(ax=axes[0])
axes[0].set_xlabel('Hour of the  day');
axes[0].set_ylabel('Average hourly demand [L/s]');
axes[0].set_title('Hour-by-hour distribution of water demand for Year#1');
axes[0].set_ylim([350,1450])

avg_year1 = df_year1.values.reshape(-1).mean()
axes[0].hlines(avg_year1,1,24, colors='r')
axes[0].text(2, 1000, f'avg={avg_year1:.2f}', fontsize=12)

# year 2
df_year2.boxplot(ax=axes[1])
axes[1].set_xlabel('Hour of the  day');
# axes[1].set_ylabel('Average hourly demand [L/s]');
axes[1].set_title('Hour-by-hour distribution of water demand for Year#2');
axes[1].set_ylim([350,1450])

avg_year2 = df_year2.values.reshape(-1).mean()
axes[1].hlines(avg_year2,1,24, colors='r')
axes[1].text(2, 1000, f'avg={avg_year2:.2f}', fontsize=12)

f.tight_layout()

# %% [markdown]
# #### Creation of sequence-to-sequence modeling dataset and data normalization

# %% [markdown]
# We now create the sequence datasets for _training_, _validating_ and _testing_ our DL methods. We will start by only using past water demands. These datasets will be created by calling one of the helper functions in the ```assignment_utils``` module. We first create the sequences for Year \#1, which will be used for training and validation.

# %%
T = 168 # number of time steps to use for prediction (168 hours = 1 week)
H = 24  # number of time steps to predict (24 hours)
X,Y=assignment_utils.create_sequences(df_year1.values.reshape(-1),T=T,H=H)
print(X.shape)
print(Y.shape)
# Out:
# (8568, 168)
# (8568, 24)

# %% [markdown]
# As you can see, each input-ouput pair is made of: 1) an input sequence of 168 hours (e.g., 1 week) and 2) an output sequence of 24 hours.

# %%
random_ix = np.random.choice(X.shape[0])
f, ax = plt.subplots(1,figsize=(10,3))
ax.plot(np.arange(T),X[0], label='X (input)')
ax.plot(np.arange(T,T+H),Y[0], label = 'Y (output)')
ax.set_title(f'X and Y for sequence #{random_ix} of the Year #1 dataset');
ax.legend();

# %% [markdown]
# These sequences are not normalized yet, and we need to split them into training and validation. We first perform the latter task and then we use ```scale_sequences``` to perform the scaling. Is important to use the scaler "fitted" for the training dataset to scale tha validation dataset and then the test dataset (Year \#2). Since the input and output variables are both water demand, we only need to fit one scaler. ```scale_sequences``` recognize whether to fit a scaler or use an existing one based on the arguments it receives when called.

# %%
# we use 15% of Year #1 for validation; we shuffle the sequences; 
# we keep track of indexes of train and validation.
X_tra, X_val, Y_tra, Y_val, ix_tra, ix_val = train_test_split(
    X, Y, np.arange(X.shape[0]), test_size=0.15, shuffle=True, random_state=42)
print(f"X_tra.shape: {X_tra.shape}, Y_tra.shape: {Y_tra.shape}")
print(f"X_val.shape: {X_val.shape}, Y_val.shape: {Y_val.shape}")
# Out:
# X_tra.shape: (7282, 168), Y_tra.shape: (7282, 24)
# X_val.shape: (1286, 168), Y_val.shape: (1286, 24)

# %% [markdown]
# Let's plot a random sequence from the training dataset

# %%
random_ix = np.random.choice(X_tra.shape[0])
f, ax = plt.subplots(1,figsize=(10,3))
ax.plot(np.arange(T),X_tra[random_ix], label='Xtra')
ax.plot(np.arange(T,T+H),Y_tra[random_ix], label = 'Ytra')
ax.set_title(f'X and Y for sequence #{random_ix} of the training dataset');

# %% [markdown]
# Now we scale all data. Remember: <u>you "fit" the scaler using training data </u>; when you develop your machine learning models, you have to assume that you have no information on validation and test data.

# %%
X_tra, scaler = assignment_utils.scale_sequences(X_tra,scaler_type='minmax')
Y_tra, _ = assignment_utils.scale_sequences(Y_tra, scaler)
X_val, _ = assignment_utils.scale_sequences(X_val, scaler)
Y_val, _ = assignment_utils.scale_sequences(Y_val, scaler)

# %% [markdown]
# As you can see, the sequences before and after normalization look the same, but the ranges are different.

# %%
f, ax = plt.subplots(1,figsize=(10,3))
ax.plot(np.arange(T),X_tra[random_ix], label='Xtra')
ax.plot(np.arange(T,T+H),Y_tra[random_ix], label = 'Ytra')
ax.set_title(f'X and Y for sequence #{random_ix} of the SCALED training dataset');

# %% [markdown]
# Before proceeding with the assignment, we now we create scaled sequences for the test dataset.

# %%
# create
X_tst,Y_tst=assignment_utils.create_sequences(df_year2.values.reshape(-1),T=T,H=H)
print(X_tst.shape)
print(Y_tst.shape)

# normalize
X_tst, _ = assignment_utils.scale_sequences(X_tst, scaler)
Y_tst, _ = assignment_utils.scale_sequences(Y_tst, scaler)
# Out:
# (8568, 168)
# (8568, 24)

# %% [markdown]
# ### <u>BEGINNING OF ASSIGNMENT</u>

# %% [markdown]
# #### Part 1. Train a Feed-forward Neural Network that will be used as benchmark.
#
# You are asked to train several FNNs architectures (between 10 and 20) to develop a good benchmark for the *water demand forecasting problem*.
#
# _Instructions_
# - Try single hidden layer as well as double hidden layer FNNs;
# - Try different activation functions for the hidden layer (e.g., ```ReLU```, ```tanh```); keep the output activation function ```linear```;
# - Limit the total number of neurons in each layer to 100;
# - Use ```dropout``` and early stopping (callback) to reduce overfitting;
# - Limit training epochs to 200 and use time stopping (callback) to reduce computational time to a max of 10 minutes for each model;
# - Save all models (e.g., using the model checkpoint callback);
# - Use the ```Adam``` optimizer, and set learning rate to 0.005;
# - Use a batch size of 32.
#
# _Questions_
# - For each trained architecture, store the *best value for the validation loss*, *number of trainable parameters*, and *training time*;
# - Select the benchmark architecture and motivate why.
# - Plot the training/validation history of the selected FNN architecture

# %%
#In this code cell everything is imported and all the preliminary work is done

from keras.layers import Dense, Flatten
import keras
from keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow_addons.callbacks import TimeStopping
import tensorflow.keras.backend as K
from time import time

def get_trainable_parameters(model):
  # this quickly gets weights for each layer
  number_of_weights = [K.count_params(w) for w in model.trainable_weights]
  # loop all layers for more details
  k = 0
  for layer in model.layers:
 #   print('_ _ _ '*10)
 #   print(layer.name)
    for weights in layer.trainable_weights:
  #    print(f'{weights.name}, \nshape={weights.shape} ===> {number_of_weights[k]}')
      k+=1
  #print('_ _ _ '*10)
  total = np.array(number_of_weights).sum().astype(int)
 # print(f'Total = {total}')
  return total

earlyStopping = EarlyStopping(monitor='val_loss', patience=50, verbose=1, 
                              min_delta=1e-4, mode='auto', restore_best_weights=True)
timeStopping = TimeStopping(seconds=600, verbose=1)


#initialise empty variables
number_of_parameters = []
i = 0

batch_size = 32 # number of samples processed before the model is updated
num_epochs = 200  # number of complete passes through the training dataset before the training stops

modeldescriptions = []
total_times = []
lowest_validation_loss = []

# %%
#A code cell which can be run time and time again to gather more and more different models

model_name = 'FNN_model_{}_weights.hdf5'.format(i)
modelCheckpoint = ModelCheckpoint(model_name, save_best_only=True, monitor='val_loss', 
                                  mode='auto', save_weights_only=True)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(50, activation=tf.nn.tanh))
model.add(tf.keras.layers.Dropout(.05))
model.add(BatchNormalization())
#model.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
#model.add(tf.keras.layers.Dropout(.2))
#model.add(BatchNormalization())
model.add(tf.keras.layers.Dense(24))


# Compiling the model adds a loss function, optimiser and metrics to track during training
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.005),
              loss='mse',
              metrics=['accuracy'])

start = time()
history = model.fit(x = X_tra, y = Y_tra, epochs=num_epochs, batch_size=batch_size, validation_data=(X_val, Y_val),callbacks = [earlyStopping, modelCheckpoint, timeStopping])
total_times.append(time()-start)
number_of_parameters.append(get_trainable_parameters(model))
modeldescriptions.append('This is model {} with 1 hidden layers (50), 5% dropout, and tanh activation'.format(i))
lowest_validation_loss.append(min(history.history["val_loss"]))
print('Number of parameters: ', number_of_parameters[i])
model.summary()
i = i+1
# Out:
# Epoch 1/200
# 228/228 [==============================] - 2s 5ms/step - loss: 0.0940 - accuracy: 0.0985 - val_loss: 0.0095 - val_accuracy: 0.1858
# Epoch 2/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0129 - accuracy: 0.1360 - val_loss: 0.0058 - val_accuracy: 0.2216
# Epoch 3/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0081 - accuracy: 0.1855 - val_loss: 0.0047 - val_accuracy: 0.2473
# Epoch 4/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0066 - accuracy: 0.2194 - val_loss: 0.0043 - val_accuracy: 0.2582
# Epoch 5/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0060 - accuracy: 0.2308 - val_loss: 0.0042 - val_accuracy: 0.2597
# Epoch 6/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0055 - accuracy: 0.2509 - val_loss: 0.0050 - val_accuracy: 0.2683
# Epoch 7/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0055 - accuracy: 0.2567 - val_loss: 0.0039 - val_accuracy: 0.2807
# Epoch 8/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0050 - accuracy: 0.2704 - val_loss: 0.0040 - val_accuracy: 0.2621
# Epoch 9/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0048 - accuracy: 0.2812 - val_loss: 0.0052 - val_accuracy: 0.2768
# Epoch 10/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0046 - accuracy: 0.2925 - val_loss: 0.0034 - val_accuracy: 0.3064
# Epoch 11/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0044 - accuracy: 0.2948 - val_loss: 0.0034 - val_accuracy: 0.3079
# Epoch 12/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0043 - accuracy: 0.3024 - val_loss: 0.0030 - val_accuracy: 0.2955
# Epoch 13/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0041 - accuracy: 0.3088 - val_loss: 0.0031 - val_accuracy: 0.3180
# Epoch 14/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0041 - accuracy: 0.3187 - val_loss: 0.0036 - val_accuracy: 0.3134
# Epoch 15/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0042 - accuracy: 0.3299 - val_loss: 0.0031 - val_accuracy: 0.3313
# Epoch 16/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0039 - accuracy: 0.3334 - val_loss: 0.0035 - val_accuracy: 0.3235
# Epoch 17/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0039 - accuracy: 0.3362 - val_loss: 0.0032 - val_accuracy: 0.2792
# Epoch 18/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0040 - accuracy: 0.3494 - val_loss: 0.0050 - val_accuracy: 0.3709
# Epoch 19/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.3476 - val_loss: 0.0032 - val_accuracy: 0.3212
# Epoch 20/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.3502 - val_loss: 0.0040 - val_accuracy: 0.3398
# Epoch 21/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.3550 - val_loss: 0.0028 - val_accuracy: 0.3981
# Epoch 22/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3542 - val_loss: 0.0034 - val_accuracy: 0.3880
# Epoch 23/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.3566 - val_loss: 0.0033 - val_accuracy: 0.3546
# Epoch 24/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0038 - accuracy: 0.3520 - val_loss: 0.0037 - val_accuracy: 0.3266
# Epoch 25/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0038 - accuracy: 0.3720 - val_loss: 0.0035 - val_accuracy: 0.3414
# Epoch 26/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3701 - val_loss: 0.0042 - val_accuracy: 0.2784
# Epoch 27/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.3605 - val_loss: 0.0051 - val_accuracy: 0.3328
# Epoch 28/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.3664 - val_loss: 0.0031 - val_accuracy: 0.3616
# Epoch 29/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0038 - accuracy: 0.3559 - val_loss: 0.0033 - val_accuracy: 0.3569
# Epoch 30/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.3542 - val_loss: 0.0034 - val_accuracy: 0.3515
# Epoch 31/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3539 - val_loss: 0.0028 - val_accuracy: 0.3663
# Epoch 32/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.3753 - val_loss: 0.0029 - val_accuracy: 0.3896
# Epoch 33/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.3581 - val_loss: 0.0037 - val_accuracy: 0.3429
# Epoch 34/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.3579 - val_loss: 0.0030 - val_accuracy: 0.3390
# Epoch 35/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3594 - val_loss: 0.0029 - val_accuracy: 0.3297
# Epoch 36/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3638 - val_loss: 0.0032 - val_accuracy: 0.3468
# Epoch 37/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.3543 - val_loss: 0.0024 - val_accuracy: 0.3997
# Epoch 38/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0037 - accuracy: 0.3647 - val_loss: 0.0038 - val_accuracy: 0.3468
# Epoch 39/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3678 - val_loss: 0.0035 - val_accuracy: 0.3087
# Epoch 40/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0038 - accuracy: 0.3577 - val_loss: 0.0034 - val_accuracy: 0.3351
# Epoch 41/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3557 - val_loss: 0.0024 - val_accuracy: 0.3748
# Epoch 42/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.3614 - val_loss: 0.0044 - val_accuracy: 0.3219
# Epoch 43/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3569 - val_loss: 0.0040 - val_accuracy: 0.3219
# Epoch 44/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3575 - val_loss: 0.0025 - val_accuracy: 0.3701
# Epoch 45/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3689 - val_loss: 0.0026 - val_accuracy: 0.3919
# Epoch 46/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0038 - accuracy: 0.3564 - val_loss: 0.0027 - val_accuracy: 0.3585
# Epoch 47/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3555 - val_loss: 0.0046 - val_accuracy: 0.3227
# Epoch 48/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3716 - val_loss: 0.0024 - val_accuracy: 0.3429
# Epoch 49/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3723 - val_loss: 0.0036 - val_accuracy: 0.3476
# Epoch 50/200
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.3687 - val_loss: 0.0031 - val_accuracy: 0.3499
# Epoch 51/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3693 - val_loss: 0.0025 - val_accuracy: 0.3600
# Epoch 52/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3650 - val_loss: 0.0028 - val_accuracy: 0.3802
# Epoch 53/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3719 - val_loss: 0.0034 - val_accuracy: 0.3585
# Epoch 54/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3577 - val_loss: 0.0027 - val_accuracy: 0.3896
# Epoch 55/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3678 - val_loss: 0.0031 - val_accuracy: 0.3756
# Epoch 56/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3715 - val_loss: 0.0035 - val_accuracy: 0.3056
# Epoch 57/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3636 - val_loss: 0.0025 - val_accuracy: 0.3950
# Epoch 58/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3643 - val_loss: 0.0031 - val_accuracy: 0.3616
# Epoch 59/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3608 - val_loss: 0.0029 - val_accuracy: 0.3033
# Epoch 60/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3741 - val_loss: 0.0027 - val_accuracy: 0.3523
# Epoch 61/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3767 - val_loss: 0.0024 - val_accuracy: 0.4075
# Epoch 62/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3682 - val_loss: 0.0031 - val_accuracy: 0.3383
# Epoch 63/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3601 - val_loss: 0.0022 - val_accuracy: 0.4067
# Epoch 64/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3602 - val_loss: 0.0024 - val_accuracy: 0.3935
# Epoch 65/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3561 - val_loss: 0.0027 - val_accuracy: 0.4230
# Epoch 66/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3518 - val_loss: 0.0023 - val_accuracy: 0.3927
# Epoch 67/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3588 - val_loss: 0.0024 - val_accuracy: 0.3880
# Epoch 68/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3651 - val_loss: 0.0026 - val_accuracy: 0.3865
# Epoch 69/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3693 - val_loss: 0.0023 - val_accuracy: 0.3779
# Epoch 70/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3669 - val_loss: 0.0023 - val_accuracy: 0.3375
# Epoch 71/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3708 - val_loss: 0.0023 - val_accuracy: 0.4020
# Epoch 72/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3569 - val_loss: 0.0030 - val_accuracy: 0.3616
# Epoch 73/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3686 - val_loss: 0.0026 - val_accuracy: 0.3725
# Epoch 74/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3643 - val_loss: 0.0026 - val_accuracy: 0.3779
# Epoch 75/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3650 - val_loss: 0.0022 - val_accuracy: 0.4075
# Epoch 76/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3561 - val_loss: 0.0029 - val_accuracy: 0.3515
# Epoch 77/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3658 - val_loss: 0.0030 - val_accuracy: 0.3896
# Epoch 78/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3628 - val_loss: 0.0021 - val_accuracy: 0.3639
# Epoch 79/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3612 - val_loss: 0.0031 - val_accuracy: 0.3017
# Epoch 80/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3643 - val_loss: 0.0027 - val_accuracy: 0.3802
# Epoch 81/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3675 - val_loss: 0.0030 - val_accuracy: 0.3888
# Epoch 82/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3612 - val_loss: 0.0033 - val_accuracy: 0.3476
# Epoch 83/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3605 - val_loss: 0.0023 - val_accuracy: 0.4129
# Epoch 84/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3650 - val_loss: 0.0025 - val_accuracy: 0.4036
# Epoch 85/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3606 - val_loss: 0.0029 - val_accuracy: 0.3530
# Epoch 86/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3639 - val_loss: 0.0027 - val_accuracy: 0.3647
# Epoch 87/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3654 - val_loss: 0.0026 - val_accuracy: 0.3616
# Epoch 88/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3684 - val_loss: 0.0025 - val_accuracy: 0.3849
# Epoch 89/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3587 - val_loss: 0.0021 - val_accuracy: 0.3561
# Epoch 90/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3676 - val_loss: 0.0023 - val_accuracy: 0.3958
# Epoch 91/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3739 - val_loss: 0.0020 - val_accuracy: 0.3935
# Epoch 92/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3642 - val_loss: 0.0021 - val_accuracy: 0.4059
# Epoch 93/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3695 - val_loss: 0.0030 - val_accuracy: 0.3484
# Epoch 94/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3673 - val_loss: 0.0026 - val_accuracy: 0.4028
# Epoch 95/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3684 - val_loss: 0.0024 - val_accuracy: 0.3989
# Epoch 96/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3713 - val_loss: 0.0023 - val_accuracy: 0.4129
# Epoch 97/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0037 - accuracy: 0.3635 - val_loss: 0.0020 - val_accuracy: 0.4152
# Epoch 98/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3726 - val_loss: 0.0023 - val_accuracy: 0.3927
# Epoch 99/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3678 - val_loss: 0.0025 - val_accuracy: 0.3771
# Epoch 100/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3683 - val_loss: 0.0028 - val_accuracy: 0.3818
# Epoch 101/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3657 - val_loss: 0.0027 - val_accuracy: 0.3585
# Epoch 102/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3763 - val_loss: 0.0023 - val_accuracy: 0.4106
# Epoch 103/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3654 - val_loss: 0.0023 - val_accuracy: 0.4292
# Epoch 104/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3713 - val_loss: 0.0022 - val_accuracy: 0.3717
# Epoch 105/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3720 - val_loss: 0.0027 - val_accuracy: 0.3942
# Epoch 106/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3691 - val_loss: 0.0024 - val_accuracy: 0.4246
# Epoch 107/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3728 - val_loss: 0.0024 - val_accuracy: 0.3802
# Epoch 108/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3682 - val_loss: 0.0026 - val_accuracy: 0.4005
# Epoch 109/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3580 - val_loss: 0.0024 - val_accuracy: 0.3694
# Epoch 110/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3717 - val_loss: 0.0023 - val_accuracy: 0.3857
# Epoch 111/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3660 - val_loss: 0.0022 - val_accuracy: 0.4393
# Epoch 112/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3731 - val_loss: 0.0025 - val_accuracy: 0.3351
# Epoch 113/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3609 - val_loss: 0.0021 - val_accuracy: 0.3771
# Epoch 114/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3792 - val_loss: 0.0022 - val_accuracy: 0.3966
# Epoch 115/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3720 - val_loss: 0.0024 - val_accuracy: 0.3911
# Epoch 116/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3683 - val_loss: 0.0021 - val_accuracy: 0.3756
# Epoch 117/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3579 - val_loss: 0.0024 - val_accuracy: 0.3670
# Epoch 118/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3698 - val_loss: 0.0024 - val_accuracy: 0.4121
# Epoch 119/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3737 - val_loss: 0.0027 - val_accuracy: 0.3981
# Epoch 120/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3572 - val_loss: 0.0023 - val_accuracy: 0.4012
# Epoch 121/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3764 - val_loss: 0.0023 - val_accuracy: 0.4059
# Epoch 122/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3662 - val_loss: 0.0027 - val_accuracy: 0.3733
# Epoch 123/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3717 - val_loss: 0.0020 - val_accuracy: 0.4238
# Epoch 124/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3830 - val_loss: 0.0022 - val_accuracy: 0.3810
# Epoch 125/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3712 - val_loss: 0.0022 - val_accuracy: 0.4160
# Epoch 126/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3689 - val_loss: 0.0027 - val_accuracy: 0.3795
# Epoch 127/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3640 - val_loss: 0.0026 - val_accuracy: 0.3460
# Epoch 128/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3759 - val_loss: 0.0023 - val_accuracy: 0.3974
# Epoch 129/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3792 - val_loss: 0.0019 - val_accuracy: 0.4036
# Epoch 130/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3662 - val_loss: 0.0019 - val_accuracy: 0.4059
# Epoch 131/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3680 - val_loss: 0.0021 - val_accuracy: 0.4184
# Epoch 132/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3743 - val_loss: 0.0024 - val_accuracy: 0.4082
# Epoch 133/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3621 - val_loss: 0.0022 - val_accuracy: 0.4005
# Epoch 134/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0033 - accuracy: 0.3577 - val_loss: 0.0021 - val_accuracy: 0.4292
# Epoch 135/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3754 - val_loss: 0.0026 - val_accuracy: 0.4253
# Epoch 136/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3673 - val_loss: 0.0020 - val_accuracy: 0.4121
# Epoch 137/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3657 - val_loss: 0.0022 - val_accuracy: 0.3950
# Epoch 138/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.3689 - val_loss: 0.0024 - val_accuracy: 0.4051
# Epoch 139/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0036 - accuracy: 0.3631 - val_loss: 0.0026 - val_accuracy: 0.3694
# Epoch 140/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3679 - val_loss: 0.0020 - val_accuracy: 0.4098
# Epoch 141/200
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0035 - accuracy: 0.3680 - val_loss: 0.0024 - val_accuracy: 0.3795
# Restoring model weights from the end of the best epoch.
# Epoch 00141: early stopping
# Number of parameters:  9774
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_52 (Dense)             (None, 50)                8450
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 50)                0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 50)                200
# _________________________________________________________________
# dense_53 (Dense)             (None, 24)                1224
# =================================================================
# Total params: 9,874
# Trainable params: 9,774
# Non-trainable params: 100
# _________________________________________________________________

# %%
print('Number of parameters: ', number_of_parameters)
print(modeldescriptions)
print(total_times)
print(lowest_validation_loss)

min_model = np.argmin(lowest_validation_loss)
print()
print('The model with the lowest validation loss was model',min_model, 'with validation loss',lowest_validation_loss[min_model-1],'and training time of',total_times[min_model-1],'seconds wherin it trained',number_of_parameters[min_model-1],'parameters. The model description is as follows:',modeldescriptions[min_model-1])
# Out:
# Number of parameters:  [4819.0, 2659.0, 10499.0, 12424.0, 14349.0, 20499.0, 26649.0, 23049.0, 23049.0, 23049.0, 23049, 23049.0, 29824.0, 19524.0, 14649, 9774]
# ['This is model 1 with 2 hidden layers (10 and 10), 2 times 20% dropout, and relu activation', 'This is model 2 with 2 hidden layers (10 and 25), 2 times 20% dropout, and relu activation', 'This is model 3 with 2 hidden layers (50 and 25), 2 times 20% dropout, and relu activation', 'This is model 4 with 2 hidden layers (50 and 50), 2 times 20% dropout, and relu activation', 'This is model 5 with 2 hidden layers (50 and 75), 2 times 20% dropout, and relu activation', 'This is model 6 with 2 hidden layers (75 and 75), 2 times 20% dropout, and relu activation', 'This is model 7 with 2 hidden layers (100 and 75), 2 times 20% dropout, and relu activation', 'This is model 8 with 2 hidden layers (75 and 100), 2 times 20% dropout, and relu activation', 'This is model 9 with 2 hidden layers (75 and 100), 2 times 20% dropout, and tanh then relu activation', 'This is model 10 with 2 hidden layers (75 and 100), 2 times 20% dropout, and tanh then tanh activation', 'This is model 11 with 2 hidden layers (75 and 100), 2 times 10% dropout, and tanh then tanh activation', 'This is model 12 with 2 hidden layers (75 and 100), 2 times 10% dropout, and relu then relu activation', 'This is model 13 with 2 hidden layers (100 and 100), 2 times 12% dropout, and relu then relu activation', 'This is model 14 with 1 hidden layers ( 100), 20% dropout, and relu activation', 'This is model 15 with 1 hidden layers ( 100), 20% dropout, and relu activation', 'This is model 16 with 1 hidden layers (50), 5% dropout, and tanh activation']
# [105.63762378692627, 94.2607786655426, 233.33313012123108, 183.71092128753662, 160.0875427722931, 147.23973035812378, 131.82616925239563, 119.62362217903137, 100.70464420318604, 180.2068612575531, 134.79580879211426, 212.68221735954285, 211.91794562339783, 188.4745364189148, 114.9930808544159, 157.19990277290344]
# [0.007878679782152176, 0.012500404380261898, 0.004998877644538879, 0.004245347809046507, 0.00429203687235713, 0.004060630686581135, 0.003988449927419424, 0.003839098382741213, 0.002513090381398797, 0.0022555633913725615, 0.0020774330478161573, 0.0018291464075446129, 0.0037543342914432287, 0.0037625294644385576, 0.003998264670372009, 0.0018916612025350332]
#
# The model with the lowest validation loss was model 11 with validation loss 0.0020774330478161573 and training time of 134.79580879211426 seconds wherin it trained 23049 parameters. The model description is as follows: This is model 11 with 2 hidden layers (75 and 100), 2 times 10% dropout, and tanh then tanh activation

# %%
## Plot to indicate how well the model fits
# setup plots
f, axes = plt.subplots(1,1)

# predict (1 step ahead)
FNN_val_pred = model.predict(X_val)

# plot predictions
axes.plot(Y_val[0], label='observed values')
axes.plot(FNN_val_pred[0], label='FNN predictions')
axes.set_title('FNN Predictions: 1 step ahead')
axes.set_xlim([0,23])
axes.legend()
f.tight_layout()

# %%
#Plotting accuracy and validation accuracy plus loss and validation loss of the model

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
ax = plt.gca()
ax.set_ylim([0,0.015])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ##Reasoning
#
# Model 11 was chosen because it gave the lowest validation loss. Since the FNN is probably not going to be competition for the RNN, we chose to only consider which FNN gives the best result instead of also considering training time and number of parameters. If we wanted to use the model for real water demand forecasting we might choose a different model based on those requirements.

# %% [markdown]
# #### Part 2. Train multiple Recurrent Neural Networks architectures.
#
# You are asked to train several RNNs architectures (between 10 and 20) to identify a suitable model for *water demand forecasting problem*.
#
# _Instructions_
# - Try SimpleRNN as well as LSTM;
# - You can also try GRU and/or double-layered RNNs;
# - Try different activation functions for the hidden layer (e.g., ```ReLU```, ```tanh```); keep the output activation function ```linear```
# - Limit the total number of neurons to 100 for layer;
# - Use dropout and early stopping (callback) to reduce overfitting;
# - Limit training epochs to 200 and use time stopping (callback) to reduce computational time to a max of 10 minutes for each model;
# - Save all models (e.g., using the model checkpoint callback)
# - Use the ```Adam``` optimizer, and set learning rate to 0.005;
# - Use a batch size of 32.
#
# _Questions_
# - For each trained architecture, store the *best value for the validation loss*, *number of trainable parameters*, and *training time*;
# - Select the most promising architecture and motivate why.
# - Did SimpleRNN units largely underperform more advanced RNNs such as LSTM? If so, why? If not, what can be the reason?
# - Plot the training/validation history of the selected RNN architecture;

# %% [markdown]
# #### Part 3. <u> Compare best FNN and RNN models </u>.
#
# You will now compare the results and predictions of the best FNN and RNN models on the test dataset.
#
# _Instructions_
# - Load the best FNN and RNN models.
# - Use the models to predict water demands for the training, validation and test dataset.
# - Visually compare the output of the two models on the test dataset. This can be done by plotting predictions and prediction errors for 5 randomly selected sequences of the test dataset.
# - Quantitatively compare the two models by computing the ```mean_absolute_error``` for the training, validation and test dataset.
# - <u> Remember to scale back predictions and observations using the ```inverse_transform``` method of the scaler.</u>
#
# _Questions_
# - Do RNNs outperform FNNs? How did you compare them?
# - How does the test ```mean_absolute_error``` compare to that measured during training and validation? Do you think the models might be overfitting?
# - If so, do you think it happens because of model limitations or because of the datasets used?
