# %% [markdown]
# # CS4305TU: Week 6 - Artificial Neural Network - Assignment
# ## Investigating neighbourhood choice behaviour using ANNs
# **7 & 11 October 2021**
#
# - Sander van Cranenburgh
# - Francisco Garrido-Valenzuela

# %% [markdown]
# ### General information
#
# * For this assignment we will use *Stated Choice data* on residential location choice, collected in:
#     - Mainz, Germany
#     - Hanover, Germany
#     - Bern, Switzerland
#     - Zurich, Switzerland
#
# - For more details on the data, see the description provided on [Brightspace](https://brightspace.tudelft.nl/d2l/le/content/399675/viewContent/2506146/View).
#
# - In total you can earn **6.0** points in this assignment.
#
# - Add **Code cells** to complement your analyses. You can draw a lot form the snippets of codes we used for the in-class exercises.
#
# ### Submission instructions
#
# - Answer the questions (code and/or text) in this notebook
# - Rename this file by adding your group nomber (e.g. Assignment_groupXX.ipynb)
# - Submit your answers both in ipynb and html format
#
# **Provide your answers in the allocated markdown boxes** (with the red font color)
#
#
# ### Set up your environment
#
# You need to set up your environment based on which platform you would like to use. In this case we offer two options:
#
# - Google Colaboratory (Colab)
# - Jupyter Lab or Notebooks (Local)
#
# #### Using Colab
#
# Students using **Colab**, just need to install **Biogeme**. Biogeme is a Python package designed for the maximum likelihood estimation of parametric models in general, with a special emphasis on discrete choice models. Just run the following notebook cell:

# %%
# Uncomment and run this cell if you are using Google Colab (keep the exclamation mark)
#!pip install biogeme
#!git clone https://github.com/cs4305tu/assignment
#root = 'assignment/'

# %% [markdown]
# #### Using local environment
#
# Students using their *local environments*, need to install all the dependencies used in this *Week 6*, to ensure compatibility, they also need to check the versions of each dependency. All dependencies are contained in the text file: **requirements.txt**. Just run the following notebook cell:

# %%
# Uncomment and run this cell if you are using your local environment (keep the exclamation mark)
# !pip3 install -r requirements.txt
root = ''
# Out:
# Requirement already satisfied: absl-py==0.14.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: aggdraw==1.3.12 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 2)) (1.3.12)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: cachetools==4.2.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 5)) (4.2.2)
# Requirement already satisfied: certifi==2021.5.30 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 6)) (2021.5.30)
# Requirement already satisfied: charset-normalizer==2.0.6 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 7)) (2.0.6)
# Requirement already satisfied: clang==5.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 8)) (5.0)
# Requirement already satisfied: cycler==0.10.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 9)) (0.10.0)
# Requirement already satisfied: Cython==0.29.24 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 10)) (0.29.24)
# Requirement already satisfied: flatbuffers==1.12 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 11)) (1.12)
# Requirement already satisfied: gast==0.4.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 12)) (0.4.0)
# Requirement already satisfied: google-auth==1.35.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 13)) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: grpcio==1.41.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 16)) (1.41.0)
# Requirement already satisfied: h5py==3.1.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 17)) (3.1.0)
# Requirement already satisfied: idna==3.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 18)) (3.2)
# Requirement already satisfied: joblib==1.0.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 19)) (1.0.1)
# Requirement already satisfied: keras==2.6.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 20)) (2.6.0)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 21)) (1.1.2)
# Requirement already satisfied: kiwisolver==1.3.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 22)) (1.3.2)
# Requirement already satisfied: Markdown==3.3.4 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 23)) (3.3.4)
# Requirement already satisfied: matplotlib==3.4.3 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 24)) (3.4.3)
# Requirement already satisfied: numpy==1.19.5 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 25)) (1.19.5)
# Requirement already satisfied: oauthlib==3.1.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 26)) (3.1.1)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 27)) (3.3.0)
# Requirement already satisfied: pandas==1.3.3 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 28)) (1.3.3)
# Requirement already satisfied: Pillow==8.3.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 29)) (8.3.2)
# Requirement already satisfied: protobuf==3.18.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 30)) (3.18.0)
# Requirement already satisfied: pyasn1==0.4.8 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 31)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 32)) (0.2.8)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 33)) (2.4.7)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 34)) (2.8.2)
# Requirement already satisfied: pytz==2021.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 35)) (2021.1)
# Requirement already satisfied: requests==2.26.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 36)) (2.26.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 37)) (1.3.0)
# Requirement already satisfied: rsa==4.7.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 38)) (4.7.2)
# Requirement already satisfied: scikit-learn==1.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 39)) (1.0)
# Requirement already satisfied: scipy==1.7.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 40)) (1.7.1)
# Requirement already satisfied: six==1.15.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 42)) (1.15.0)
# Requirement already satisfied: tensorboard==2.6.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 44)) (2.6.0)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 45)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 46)) (1.8.0)
# Requirement already satisfied: tensorflow-estimator==2.6.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 48)) (2.6.0)
# Requirement already satisfied: termcolor==1.1.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 49)) (1.1.0)
# Requirement already satisfied: threadpoolctl==2.2.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 50)) (2.2.0)
# Requirement already satisfied: tqdm==4.62.3 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 51)) (4.62.3)
# Requirement already satisfied: typing-extensions==3.7.4.3 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 52)) (3.7.4.3)
# Requirement already satisfied: Unidecode==1.3.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 53)) (1.3.2)
# Requirement already satisfied: urllib3==1.26.7 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 54)) (1.26.7)
# Requirement already satisfied: visualkeras==0.0.2 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 55)) (0.0.2)
# Requirement already satisfied: Werkzeug==2.0.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 56)) (2.0.1)
# Requirement already satisfied: wrapt==1.12.1 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from -r requirements.txt (line 57)) (1.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from astunparse==1.6.3->-r requirements.txt (line 3)) (0.37.0)
# Collecting biogeme==3.2.8
#   Using cached biogeme-3.2.8-cp38-cp38-win_amd64.whl (894 kB)
# Requirement already satisfied: setuptools>=40.3.0 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\site-packages (from google-auth==1.35.0->-r requirements.txt (line 13)) (56.0.0)
# Collecting seaborn==0.11.2
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting sklearn==0.0
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting tensorflow==2.6.0
#   Using cached tensorflow-2.6.0-cp38-cp38-win_amd64.whl (423.2 MB)
# Requirement already satisfied: colorama in c:\users\wytse\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from tqdm==4.62.3->-r requirements.txt (line 51)) (0.4.4)
# Installing collected packages: tensorflow, sklearn, seaborn, biogeme
# ERROR: Could not install packages due to an EnvironmentError: [Errno 2] No such file or directory: 'C:\\Users\\wytse\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python38\\site-packages\\tensorflow\\include\\external\\com_github_grpc_grpc\\src\\core\\ext\\filters\\client_channel\\lb_policy\\grpclb\\client_load_reporting_filter.h'
#
# WARNING: You are using pip version 20.3.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\wytse\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### Required Python packages
#
# In the following cell add all the packages you need to finish this assignment.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Opening the database

# %%
# Load the data into a dataframe
df = pd.read_csv('neighbourhood_choice2018.dat', sep='\t')
df.head()
# Out:
#    ID  ID2  STORES1  TRANSPORT1  CITY1  NOISE1  GREEN1  FOREIGN1  STORES2  \
# 0   2    5       10           5      1       2       2       0.4       15
# 1   2    6       15           5      4       4       1       0.1        2
# 2   2    7       10          15      1       3       1       0.4       15
# 3   2    8       15          15      5       4       4       0.4        2
# 4   3    9       15           5      5       1       3       0.4        2
#
#    TRANSPORT2  ...  NOISE3  GREEN3  FOREIGN3  CHOICE  SSTADT  RESPCITY  WOMAN  \
# 0          10  ...       4       4       0.2       1       3         3      0
# 1          10  ...       2       3       0.3       2       3         3      0
# 2           2  ...       1       3       0.2       3       3         3      0
# 3           2  ...       2       2       0.2       2       3         3      0
# 4          10  ...       3       1       0.2       2       2         2      1
#
#    AGE  ENVCONC  COMPLETE
# 0   42      3.0         1
# 1   42      3.0         1
# 2   42      3.0         1
# 3   42      3.0         1
# 4   41      4.5         1
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Q1. Do a proper descriptive analysis of the data set (1.0 pt)
#
# It is good practice do a descriptive analysis of the data you want to model, prior to the real modelling. So inspect e.g. what levels the attributes (features) take, correlations, class (im)balances, redudant variables, missing values, etc. to attain a good feeling for the data.

# %%
print('The amount of choice experiments in the dataset is', len(df))

#Figuring out which city is which
citylist1 = df.index[df['RESPCITY'] == 1].tolist()
citylist2 = df.index[df['RESPCITY'] == 2].tolist()
citylist3 = df.index[df['RESPCITY'] == 3].tolist()
citylist4 = df.index[df['RESPCITY'] == 4].tolist()
print('Respondents in city 1:',int(len(citylist1)/4))
print('Respondents in city 2:',int(len(citylist2)/4))
print('Respondents in city 3:',int(len(citylist3)/4))
print('Respondents in city 4:',int(len(citylist4)/4))

#Correlations between columns
print(df.corr(method ='pearson'))

#Class imbalance investigation
choice1list = df.index[df['CHOICE'] == 1].tolist()
choice2list = df.index[df['CHOICE'] == 2].tolist()
choice3list = df.index[df['CHOICE'] == 3].tolist()
print('Amount of times option 1 was chosen:', len(choice1list))
print('Amount of times option 2 was chosen:', len(choice2list))
print('Amount of times option 3 was chosen:', len(choice3list))

#Redundant values
Redundantlist = df.index[df['SSTADT'] != df['RESPCITY']].tolist()
print('The amount of times the Responder city was not choosing in the city of interest was:', len(Redundantlist))

#Where was the survey not completed?
completelist = df.index[df['COMPLETE'] == 0].tolist()
print('The indices of choices where the survey was not completed are:',completelist)
# Out:
# The amount of choice experiments in the dataset is 9720
# Respondents in city 1: 573
# Respondents in city 2: 431
# Respondents in city 3: 790
# Respondents in city 4: 636
#                   ID       ID2   STORES1  TRANSPORT1     CITY1    NOISE1  \
# ID          1.000000  1.000000 -0.001783   -0.003597  0.006020  0.009978
# ID2         1.000000  1.000000 -0.001794   -0.003600  0.006038  0.009993
# STORES1    -0.001783 -0.001794  1.000000   -0.003910  0.003013 -0.009428
# TRANSPORT1 -0.003597 -0.003600 -0.003910    1.000000 -0.004319 -0.006553
# CITY1       0.006020  0.006038  0.003013   -0.004319  1.000000 -0.012976
# NOISE1      0.009978  0.009993 -0.009428   -0.006553 -0.012976  1.000000
# GREEN1     -0.004412 -0.004418  0.001027    0.000840 -0.005636  0.004634
# FOREIGN1    0.006491  0.006487 -0.000476   -0.006204  0.002963  0.003638
# STORES2    -0.003277 -0.003268 -0.161996   -0.009329  0.000112  0.003628
# TRANSPORT2 -0.012468 -0.012480  0.008735   -0.171306 -0.005273  0.009412
# CITY2      -0.003119 -0.003110  0.004307    0.008123 -0.104974  0.004718
# NOISE2     -0.007415 -0.007430  0.005174   -0.000539  0.007000 -0.195458
# GREEN2      0.007645  0.007640  0.004693    0.000580 -0.002623 -0.008544
# FOREIGN2    0.000962  0.000950 -0.008896    0.014210 -0.002517 -0.002450
# STORES3    -0.001742 -0.001731 -0.673608    0.007105 -0.014037  0.001343
# TRANSPORT3  0.011210  0.011217 -0.003105   -0.674042  0.001573 -0.006228
# CITY3      -0.001484 -0.001498 -0.003101   -0.005106 -0.800002  0.013448
# NOISE3     -0.001532 -0.001527 -0.010093    0.006780  0.014271 -0.600042
# GREEN3     -0.000041 -0.000025  0.002757    0.006566  0.005335 -0.003761
# FOREIGN3    0.009138  0.009136 -0.000185   -0.007088 -0.004067  0.003969
# CHOICE      0.014877  0.014887  0.060248    0.197005  0.153796  0.236012
# SSTADT      0.001364  0.001364 -0.013949   -0.010080  0.005061 -0.005589
# RESPCITY    0.001364  0.001364 -0.013949   -0.010080  0.005061 -0.005589
# WOMAN      -0.000884 -0.000884  0.012194   -0.004547 -0.007383  0.000178
# AGE         0.008534  0.008534  0.013050    0.001065 -0.003575  0.020722
# ENVCONC    -0.015715 -0.015715 -0.015544    0.008481 -0.004401 -0.004773
# COMPLETE    0.011881  0.011881  0.004566   -0.005631  0.005286 -0.010012
#
#               GREEN1  FOREIGN1   STORES2  TRANSPORT2  ...    NOISE3    GREEN3  \
# ID         -0.004412  0.006491 -0.003277   -0.012468  ... -0.001532 -0.000041
# ID2        -0.004418  0.006487 -0.003268   -0.012480  ... -0.001527 -0.000025
# STORES1     0.001027 -0.000476 -0.161996    0.008735  ... -0.010093  0.002757
# TRANSPORT1  0.000840 -0.006204 -0.009329   -0.171306  ...  0.006780  0.006566
# CITY1      -0.005636  0.002963  0.000112   -0.005273  ...  0.014271  0.005335
# NOISE1      0.004634  0.003638  0.003628    0.009412  ... -0.600042 -0.003761
# GREEN1      1.000000 -0.006601  0.006262    0.006174  ...  0.002672 -0.600047
# FOREIGN1   -0.006601  1.000000 -0.004898    0.001660  ... -0.002485 -0.007879
# STORES2     0.006262 -0.004898  1.000000    0.003833  ...  0.002457 -0.004403
# TRANSPORT2  0.006174  0.001660  0.003833    1.000000  ... -0.011042 -0.007546
# CITY2       0.005534 -0.000038 -0.000117   -0.015405  ... -0.004002  0.001874
# NOISE2      0.002909 -0.005781 -0.011270    0.002137  ... -0.204744  0.001706
# GREEN2     -0.195402  0.014546 -0.017484    0.001138  ...  0.006911 -0.206676
# FOREIGN2   -0.009551 -0.189088  0.009584   -0.001646  ...  0.001679  0.005090
# STORES3     0.002035  0.000789 -0.160605   -0.011004  ...  0.006420  0.000872
# TRANSPORT3  0.000260  0.004804  0.003132   -0.151045  ...  0.003905 -0.007251
# CITY3      -0.001753  0.000983  0.003521    0.003833  ... -0.015189  0.002886
# NOISE3      0.002672 -0.002485  0.002457   -0.011042  ...  1.000000 -0.003789
# GREEN3     -0.600047 -0.007879 -0.004403   -0.007546  ... -0.003789  1.000000
# FOREIGN3    0.012226 -0.600033  0.000403   -0.003186  ... -0.004709 -0.000274
# CHOICE     -0.269186  0.095885 -0.000457   -0.095360  ... -0.217670  0.221183
# SSTADT      0.006193 -0.007675  0.001931    0.017369  ...  0.000233 -0.000869
# RESPCITY    0.006193 -0.007675  0.001931    0.017369  ...  0.000233 -0.000869
# WOMAN       0.001923  0.002411 -0.002827    0.004260  ...  0.000198 -0.005907
# AGE        -0.004805  0.005237  0.004758   -0.005703  ... -0.011054  0.000242
# ENVCONC     0.009038 -0.021700  0.013104    0.015106  ... -0.004754 -0.000879
# COMPLETE   -0.004898  0.013481 -0.014279   -0.012433  ...  0.011109 -0.001098
#
#             FOREIGN3    CHOICE    SSTADT  RESPCITY     WOMAN       AGE  \
# ID          0.009138  0.014877  0.001364  0.001364 -0.000884  0.008534
# ID2         0.009136  0.014887  0.001364  0.001364 -0.000884  0.008534
# STORES1    -0.000185  0.060248 -0.013949 -0.013949  0.012194  0.013050
# TRANSPORT1 -0.007088  0.197005 -0.010080 -0.010080 -0.004547  0.001065
# CITY1      -0.004067  0.153796  0.005061  0.005061 -0.007383 -0.003575
# NOISE1      0.003969  0.236012 -0.005589 -0.005589  0.000178  0.020722
# GREEN1      0.012226 -0.269186  0.006193  0.006193  0.001923 -0.004805
# FOREIGN1   -0.600033  0.095885 -0.007675 -0.007675  0.002411  0.005237
# STORES2     0.000403 -0.000457  0.001931  0.001931 -0.002827  0.004758
# TRANSPORT2 -0.003186 -0.095360  0.017369  0.017369  0.004260 -0.005703
# CITY2      -0.006618 -0.067889  0.003128  0.003128 -0.005687 -0.008753
# NOISE2      0.002836 -0.168685  0.002147  0.002147  0.008286  0.002572
# GREEN2     -0.008674  0.025195  0.001105  0.001105 -0.014871 -0.010279
# FOREIGN2   -0.206710 -0.048984  0.011965  0.011965 -0.006778 -0.019457
# STORES3     0.000769 -0.079537  0.009068  0.009068 -0.004919 -0.015231
# TRANSPORT3  0.008296 -0.187422 -0.014323 -0.014323  0.004243  0.014838
# CITY3      -0.001789 -0.165109 -0.001203 -0.001203  0.010116  0.001727
# NOISE3     -0.004709 -0.217670  0.000233  0.000233  0.000198 -0.011054
# GREEN3     -0.000274  0.221183 -0.000869 -0.000869 -0.005907  0.000242
# FOREIGN3    1.000000 -0.064269  0.005271  0.005271 -0.006210 -0.004781
# CHOICE     -0.064269  1.000000 -0.009905 -0.009905  0.002445  0.007536
# SSTADT      0.005271 -0.009905  1.000000  1.000000 -0.041425 -0.031247
# RESPCITY    0.005271 -0.009905  1.000000  1.000000 -0.041425 -0.031247
# WOMAN      -0.006210  0.002445 -0.041425 -0.041425  1.000000  0.557746
# AGE        -0.004781  0.007536 -0.031247 -0.031247  0.557746  1.000000
# ENVCONC    -0.012423 -0.006206  0.000542  0.000542  0.059566  0.062427
# COMPLETE    0.012814  0.000247  0.015114  0.015114 -0.282974 -0.507324
#
#              ENVCONC  COMPLETE
# ID         -0.015715  0.011881
# ID2        -0.015715  0.011881
# STORES1    -0.015544  0.004566
# TRANSPORT1  0.008481 -0.005631
# CITY1      -0.004401  0.005286
# NOISE1     -0.004773 -0.010012
# GREEN1      0.009038 -0.004898
# FOREIGN1   -0.021700  0.013481
# STORES2     0.013104 -0.014279
# TRANSPORT2  0.015106 -0.012433
# CITY2       0.012427 -0.004748
# NOISE2      0.008521 -0.007634
# GREEN2      0.004595  0.004137
# FOREIGN2    0.009985  0.002959
# STORES3     0.012805 -0.001049
# TRANSPORT3 -0.011986  0.002582
# CITY3      -0.003578  0.001850
# NOISE3     -0.004754  0.011109
# GREEN3     -0.000879 -0.001098
# FOREIGN3   -0.012423  0.012814
# CHOICE     -0.006206  0.000247
# SSTADT      0.000542  0.015114
# RESPCITY    0.000542  0.015114
# WOMAN       0.059566 -0.282974
# AGE         0.062427 -0.507324
# ENVCONC     1.000000 -0.875194
# COMPLETE   -0.875194  1.000000
#
# [27 rows x 27 columns]
# Amount of times option 1 was chosen: 3440
# Amount of times option 2 was chosen: 3266
# Amount of times option 3 was chosen: 3014
# The amount of times the Responder city was not choosing in the city of interest was: 0
# The indices of choices where the survey was not completed are: [276, 277, 278, 279, 568, 569, 570, 571, 648, 649, 650, 651, 712, 713, 714, 715, 728, 729, 730, 731, 760, 761, 762, 763, 836, 837, 838, 839, 1004, 1005, 1006, 1007, 1124, 1125, 1126, 1127, 1252, 1253, 1254, 1255, 1384, 1385, 1386, 1387, 1404, 1405, 1406, 1407, 1496, 1497, 1498, 1499, 1880, 1881, 1882, 1883, 1900, 1901, 1902, 1903, 2648, 2649, 2650, 2651, 2652, 2653, 2654, 2655, 2868, 2869, 2870, 2871, 3152, 3153, 3154, 3155, 3328, 3329, 3330, 3331, 3360, 3361, 3362, 3363, 3416, 3417, 3418, 3419, 3512, 3513, 3514, 3515, 3668, 3669, 3670, 3671, 3672, 3673, 3674, 3675, 3812, 3813, 3814, 3815, 3860, 3861, 3862, 3863, 4104, 4105, 4106, 4107, 4272, 4273, 4274, 4275, 4308, 4309, 4310, 4311, 4368, 4369, 4370, 4371, 4424, 4425, 4426, 4427, 4584, 4585, 4586, 4587, 4616, 4617, 4618, 4619, 5420, 5421, 5422, 5423, 5496, 5497, 5498, 5499, 5812, 5813, 5814, 5815, 6044, 6045, 6046, 6047, 6400, 6401, 6402, 6403, 6456, 6457, 6458, 6459, 6584, 6585, 6586, 6587, 6684, 6685, 6686, 6687, 6696, 6697, 6698, 6699, 6788, 6789, 6790, 6791, 6812, 6813, 6814, 6815, 6856, 6857, 6858, 6859, 7004, 7005, 7006, 7007, 7016, 7017, 7018, 7019, 7312, 7313, 7314, 7315, 7444, 7445, 7446, 7447, 7568, 7569, 7570, 7571, 7632, 7633, 7634, 7635, 7876, 7877, 7878, 7879, 8044, 8045, 8046, 8047, 8148, 8149, 8150, 8151, 8304, 8305, 8306, 8307, 8472, 8473, 8474, 8475, 8840, 8841, 8842, 8843, 8948, 8949, 8950, 8951, 9180, 9181, 9182, 9183, 9512, 9513, 9514, 9515]

# %% [markdown]
# <font color='red'>
#
# **ANSWER Q1** <br>

# %% [markdown]
# The attribute Stores takes levels: 2, 5, 10 and 15. This is the time to walk to a grocery store in minutes.
#
# The attribute Transport takes levels: 2, 5, 10 and 15. This is the time to walk to public transportation in minutes.
#
# The attribute City takes levels: 1, 2, 4 and 5. Meaning 1: below 1km, 2: 1 to 2 km, 4: 3 to 4 km or 5: over 4km distance to the city center
#
# The attribute Noise takes levels: 1, 2, 3 and 4. Meaning street traffic noise is 1: None, 2: little, 3: medium, 4: high.
#
# The attribute Noise takes levels: 1, 2, 3 and 4. Meaning there are various amounts of green areas in the residential area with 1: None, 2: (very) few, 3: some, 4: many.
#
# The attribute Foreigner takes levels: 0.1, 0.2, 0.3 and 0.4, meaning that there are 10%, 20%, 30% or 40% foreigners of total inhabitants living in the residential area
#
# The attribute Choice can take tevels 1, 2, 3 indicating which option was chosen.
#
# The attribute SSTADT can take values 1, 2, 3, 4 indicating which city the options were in.
#
# The attribute RESPCITY can take values 1, 2, 3, 4 indicating in which city the respondent is currently living. Since in the word document the total respondents was recorded, we can deduce from the occurences in RESPCITY that value 1 is Mainz, value 2 is Hannover, value 3 is Bern and value 4 is Zurich.
#
# The attributes WOMAN and AGE speak for themselves and can take values 0 or 1, or 18 to 70 (with 99999 as "missing value")
#
# And lastly ENVCONC is the environmental concern, which can take on values 1 through 5.

# %% [markdown]
# ------------------------------------------------------
# Some correlations can be seen in the code output above. I
#
# The classes are slightly inbalanced because option 1 was chosen 3440 times, option 2 was chosen 3266 times and option 3 was chosen 3014 times. This is important to keep in mind since the model might learn that option 1 is slightly more desireable, even though it is supposed to be random so that is not what we want the model to learn.
#
# Since we can see that RESPCITY is always equal to SSTADT, we can say one of the columns is redundant and can be thrown away.

# %% [markdown]
# ### Q2. Estimate a RUM-MNL discrete choice model (1.0 pt)
#
# Assume utility is linear additive-utility:
#
# $ V_{in} = \sum_{m}\beta_m x_{imn}$
#
# And estimate marginal utilities (i.e. betas) for:
#
# 1. Distance to Transport [min] (**Note** that distances are given in minutes)
# 2. Distance to City [km]
# 3. Distance to Stores [min] (**Note** that distances are given in minutes)
# 4. Traffic Noise
# 5. Green area
# 6. Share of foreigners [%]
#
# **Note:** Do not add any other variables (features) to the model.
#
# **To get the scores, address the following:**
#
# - (A) Report the parameter estimates, and interpret them. i.e. do they have the expected sign? (0.5 pts)
# - (B) Compute and report the cross-entropy (0.5 pts)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import biogeme.biogeme as bio
import biogeme.database as db
import biogeme.optimization as opt
import biogeme.messaging as msg
from biogeme import models
from biogeme.expressions import Beta
from sklearn.metrics import log_loss

database = db.Database('city_choicedata', df)

globals().update(database.variables)
B_transport = Beta('B_transport', 0, None, None, 0)
B_city = Beta('B_city', 0, None, None, 0)
B_store = Beta('B_store', 0, None, None, 0)
B_noise = Beta('B_noise', 0, None, None, 0)
B_green = Beta('B_green', 0, None, None, 0)
B_foreign = Beta('B_foreign', 0, None, None, 0)
# Utility functions
V1 = B_transport * TRANSPORT1 + B_city * CITY1 + B_store * STORES1 + B_noise * NOISE1 + B_green * GREEN1 + B_foreign * FOREIGN1
V2 = B_transport * TRANSPORT2 + B_city * CITY2 + B_store * STORES2 + B_noise * NOISE2 + B_green * GREEN2 + B_foreign * FOREIGN2
V3 = B_transport * TRANSPORT3 + B_city * CITY3 + B_store * STORES3 + B_noise * NOISE3 + B_green * GREEN3 + B_foreign * FOREIGN3

# Associate utility functions with the numbering of alternatives in df.CHOICE
V = {1: V1, 2: V2, 3: V3}
av = {1: 1, 2: 1, 3: 1}

# Definition of the model. This is the contribution of each observation to the log likelihood function.
prob = models.loglogit(V, av, CHOICE)

# Create the Biogeme object
biogeme = bio.BIOGEME(database, prob)
biogeme.modelName = 'Discrete choice model of living situation'
biogeme.generatePickle = False
biogeme.generateHtml = False

# Calculate the null log likelihood for reporting.
biogeme.calculateNullLoglikelihood(av)

# Estimate the parameters
results = biogeme.estimate()

# Report the results in a pandas table
print('Estimated parameters')
print('----------')
pandasResults = results.getEstimatedParameters()
print(pandasResults[['Value','Std err','t-test','p-value']])

# Get the estimated betas from the discrete choice model
betas = results.getBetaValues()


# Define compute objects
prob_1 = models.logit(V, av, 1)
prob_2 = models.logit(V, av, 2)
prob_3 = models.logit(V, av, 3)

# Define dictionary
simulate_dict = {
    'Prob_1': prob_1,
    'Prob_2': prob_2,
    'Prob_3': prob_3}

# Create Biogeme object
simulator = bio.BIOGEME(database, simulate_dict)

# Compute probabilities using the estimated choice model
probs_DCM = simulator.simulate(betas)

# Compute the cross-entropy for the DCM
cross_entropy_DCM = log_loss(df.CHOICE,probs_DCM)

print()
print('The cross-entropy of the DCM is:',"{:.3f}".format(cross_entropy_DCM))


betas = results.getBetaValues()
print(betas)
# Out:
# Estimated parameters
# ----------
#                 Value   Std err     t-test  p-value
# B_city      -0.167377  0.007949 -21.055742      0.0
# B_foreign   -1.196023  0.109408 -10.931775      0.0
# B_green      0.415894  0.011616  35.802485      0.0
# B_noise     -0.437468  0.011335 -38.594267      0.0
# B_store     -0.034433  0.002577 -13.363956      0.0
# B_transport -0.073962  0.002548 -29.026039      0.0
#
# The cross-entropy of the DCM is: 0.889
# {'B_city': -0.16737747138223225, 'B_foreign': -1.1960226374851375, 'B_green': 0.41589443719979674, 'B_noise': -0.43746767290445493, 'B_store': -0.03443252044629582, 'B_transport': -0.07396196746736038}

# %% [markdown]
# <font color='red'>
#
# **ANSWER Q2** <br>

# %% [markdown]
# The estimated parameters are:
#
# B_city $\approx$ -0.167
#
# B_foreign $\approx$ -1.195
#
# B_green $\approx$ 0.416
#
# B_noise $\approx$ -0.437
#
# B_store $\approx$ -0.034
#
# B_transport $\approx$ -0.074
#
# These parameters make sense since people prefer to not live far from the city, grocery store and public transportation, with a lot of foreigners and with a lot of noise. So therefore the betas have a negative sign. But they do prefer to live in an area with a lot of green, which has a positive beta in our results.
#
# The cross-entropy was computed to be 0.894

# %% [markdown]
# ### Q3. Based on your results, compute the WtP of the average decision maker to reduce the share of foreigners in a neighbourhood by 1 percentage point in terms of the distance to the grocery stores (0.5 pts)
#
# Thus, the answer must be of the following form: .... [minutes/percentage point].

# %%
B_foreign =-1.195
B_store =-0.034
Wtp=B_store/B_foreign
print('Willingness to Pay estimate         = ', "{:.2f}".format(Wtp),' minutes per less percentage of foreigners')
# Out:
# Willingness to Pay estimate         =  0.03  minutes per less percentage of foreigners

# %% [markdown]
# <font color='red'>
#
# **ANSWER Q3** <br>

# %% [markdown]
# Willingness to Pay estimate = 0.03 minutes per less percentage of foreigners

# %% [markdown]
# ### Q4. Train a hybrid RUM-MNL-ANN model (1.5 pts)
#
# Since we are interested in the WtP of Q3, make sure when building the hybrid model to place the features of the share of foreigners and of the distance to the grocery stores in the *MNL part of the model*. For the *ANN part of the model* use 2 hidden layers, with 5 nodes each.
#
#
# **To get the scores, address the following:**
#
#
# - (A) Build the model, plot the loss as a function of the epochs & report the cross entropy of your final model based on the test data. (1.0 pt)
# - (B) Compare the model performance to that of the discrete choice model. Interpret the result. (0.5 pts)

# %%
import tensorflow as tf
print("Using tensorflow ",tf.__version__)
import pandas as pd
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K
from keras.layers import Input, Dense, Activation
from keras.layers import Conv2D, Add, Reshape
from keras.models import Model
from keras.utils.np_utils import to_categorical   
import matplotlib.pyplot as plt
import numpy as np

# Import ML packaged and modules
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, log_loss
NALT = 3  
no_X_MNL = 2 
no_X_ANN = 18
num_nodes = 5 
nEpoch = 500  
# INPUT FOR MNL PART
X_MNL = Input((no_X_MNL, NALT,1), name = 'Features2MNL')

# COMPUTE UTILITY FOR MNL
V_MNL = Conv2D(filters = 1, kernel_size = [no_X_MNL,1], strides = (1,1), padding = 'valid', name = 'MNL_layer', use_bias = False, trainable = True)(X_MNL)
# INPUT FOR ANN PART
X_ANN = Input((no_X_ANN), name ='Features2ANN')

# CREATE HIDDEN LAYER(S) OF ANN
layer1_ANN = Dense(units = num_nodes, name = "ANN_layer1", use_bias = True)(X_ANN) 
layer2_ANN = Dense(units = num_nodes, name = "ANN_layer2", use_bias = True)(layer1_ANN)

# COMPUTE UTILITY FOR ANN 
V_ANN = Dense(units = NALT, name = "V_ANN")(layer2_ANN) 

# RESHAPE TENSORS TO [1 X NALT]
V_MNL = Reshape([NALT], name = 'Flatten_Dim_MNL')(V_MNL)
V_ANN = Reshape([NALT], name = 'Flatten_Dim_ANN')(V_ANN) 

# SUM THE UTILITIES OF BOTH MODEL PARTS
V_MNL_ANN = Add(name = "Combining_Vs")([V_MNL,V_ANN])

# CREATE LOGIT (AKA SOFTMAX ) OUTPUT LAYER
logits = Activation('softmax', name = 'Probability')(V_MNL_ANN)

# BUILD THE MODEL
model = Model(inputs = [X_MNL, X_ANN], outputs = logits)

# Define the features and the output class
X = df[['STORES1','TRANSPORT1','CITY1','NOISE1','GREEN1','FOREIGN1','STORES2','TRANSPORT2','CITY2','NOISE2','GREEN2','FOREIGN2','STORES3','TRANSPORT3','CITY3','NOISE3','GREEN3','FOREIGN3','SSTADT',	'RESPCITY',	'WOMAN',	'AGE']]
					
# Define the output target
Y = df['CHOICE']
Y_cat = to_categorical(Y-1, num_classes = 3)
# Create x input for MNL layer, and rescale
scale = 100 # We cannot just use the sklearn scaler here, as it is import for the interpretation later how the input data are scaled. 

x_mnl = np.array([[np.divide(X['STORES1'], scale), np.divide(X['FOREIGN1'], scale)],
                  [np.divide(X['STORES2'], scale), np.divide(X['FOREIGN2'], scale)],
                  [np.divide(X['STORES3'], scale), np.divide(X['FOREIGN3'], scale)]])
x_mnl = np.swapaxes(x_mnl, 0, 2)
x_mnl = np.expand_dims(x_mnl, 3)
print('Shape of x_mnl', x_mnl.shape)

# Create x input for ANN layer
x_ann = np.array([[ X['CITY1'],X['TRANSPORT1'], X['NOISE1'], X['GREEN1'],X['TRANSPORT2'], X['CITY2'],X['TRANSPORT2'], X['NOISE2'], X['GREEN2'], X['TRANSPORT3'], X['CITY3'],X['TRANSPORT3'], X['NOISE3'], X['GREEN3'], X['SSTADT'], X['WOMAN'],X['RESPCITY'], X['AGE']]])
x_ann = np.squeeze(np.swapaxes(x_ann, 0, 2))

# Rescale input for the ANN part
scaler = StandardScaler()  
scaler.fit(x_ann)  
x_ann = scaler.transform(x_ann)  
print('Shape of x_ann',x_ann.shape)

# Split the data into a training and test part
X_mnl_train, X_mnl_test, Y_train, Y_test = train_test_split(x_mnl, Y_cat, random_state = 1, test_size = 0.35)
X_ann_train, X_ann_test, Y_train, Y_test = train_test_split(x_ann, Y_cat, random_state = 1, test_size = 0.35)
print('Total number of obervations in the data set = ', len(x_mnl))
print('Number of obervations in the training set   = ', len(X_mnl_train))
print('Number of obervations in the test set       = ', len(X_mnl_test))

model.compile(optimizer = Adam(learning_rate = 1e-2), metrics = ["accuracy"], loss = 'categorical_crossentropy')
model.summary()

# Train the model
early_stopping = EarlyStopping(patience = 4, monitor = 'val_loss')
history = model.fit([X_mnl_train, X_ann_train],Y_train, batch_size=len(X_mnl_train), epochs = nEpoch, verbose = 1, validation_data = ([X_mnl_test, X_ann_test], Y_test), callbacks = [early_stopping])

betas_layer = model.get_layer(name = 'MNL_layer')
betas = betas_layer.get_weights()
print('The cross-entropy on the test data of the tensor flow ANN is',"{:.3f}".format(history.history['loss'][-1]))
# Out:
# Using tensorflow  2.6.0
# Shape of x_mnl (9720, 2, 3, 1)
# Shape of x_ann (9720, 18)
# Total number of obervations in the data set =  9720
# Number of obervations in the training set   =  6318
# Number of obervations in the test set       =  3402
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Features2ANN (InputLayer)       [(None, 18)]         0
# __________________________________________________________________________________________________
# ANN_layer1 (Dense)              (None, 5)            95          Features2ANN[0][0]
# __________________________________________________________________________________________________
# Features2MNL (InputLayer)       [(None, 2, 3, 1)]    0
# __________________________________________________________________________________________________
# ANN_layer2 (Dense)              (None, 5)            30          ANN_layer1[0][0]
# __________________________________________________________________________________________________
# MNL_layer (Conv2D)              (None, 1, 3, 1)      2           Features2MNL[0][0]
# __________________________________________________________________________________________________
# V_ANN (Dense)                   (None, 3)            18          ANN_layer2[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_MNL (Reshape)       (None, 3)            0           MNL_layer[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_ANN (Reshape)       (None, 3)            0           V_ANN[0][0]
# __________________________________________________________________________________________________
# Combining_Vs (Add)              (None, 3)            0           Flatten_Dim_MNL[0][0]
#                                                                  Flatten_Dim_ANN[0][0]
# __________________________________________________________________________________________________
# Probability (Activation)        (None, 3)            0           Combining_Vs[0][0]
# ==================================================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 442ms/step - loss: 1.2140 - accuracy: 0.3090 - val_loss: 1.1654 - val_accuracy: 0.3474
# Epoch 2/500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1701 - accuracy: 0.3378 - val_loss: 1.1274 - val_accuracy: 0.3883
# Epoch 3/500
# 1/1 [==============================] - 0s 27ms/step - loss: 1.1343 - accuracy: 0.3791 - val_loss: 1.0964 - val_accuracy: 0.4274
# Epoch 4/500
# 1/1 [==============================] - 0s 26ms/step - loss: 1.1054 - accuracy: 0.4164 - val_loss: 1.0714 - val_accuracy: 0.4447
# Epoch 5/500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0821 - accuracy: 0.4261 - val_loss: 1.0511 - val_accuracy: 0.4556
# Epoch 6/500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0631 - accuracy: 0.4375 - val_loss: 1.0344 - val_accuracy: 0.4709
# Epoch 7/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0474 - accuracy: 0.4547 - val_loss: 1.0203 - val_accuracy: 0.5079
# Epoch 8/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0340 - accuracy: 0.4935 - val_loss: 1.0082 - val_accuracy: 0.5079
# Epoch 9/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0222 - accuracy: 0.4935 - val_loss: 0.9973 - val_accuracy: 0.5082
# Epoch 10/500
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0115 - accuracy: 0.4935 - val_loss: 0.9874 - val_accuracy: 0.5082
# Epoch 11/500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0015 - accuracy: 0.4934 - val_loss: 0.9782 - val_accuracy: 0.5118
# Epoch 12/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9920 - accuracy: 0.5013 - val_loss: 0.9694 - val_accuracy: 0.5241
# Epoch 13/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9828 - accuracy: 0.5128 - val_loss: 0.9610 - val_accuracy: 0.5526
# Epoch 14/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9738 - accuracy: 0.5396 - val_loss: 0.9530 - val_accuracy: 0.5585
# Epoch 15/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9652 - accuracy: 0.5473 - val_loss: 0.9453 - val_accuracy: 0.5588
# Epoch 16/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9568 - accuracy: 0.5473 - val_loss: 0.9381 - val_accuracy: 0.5588
# Epoch 17/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.9489 - accuracy: 0.5473 - val_loss: 0.9313 - val_accuracy: 0.5741
# Epoch 18/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9416 - accuracy: 0.5497 - val_loss: 0.9251 - val_accuracy: 0.5879
# Epoch 19/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9348 - accuracy: 0.5590 - val_loss: 0.9195 - val_accuracy: 0.5891
# Epoch 20/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9287 - accuracy: 0.5662 - val_loss: 0.9146 - val_accuracy: 0.5891
# Epoch 21/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9233 - accuracy: 0.5685 - val_loss: 0.9103 - val_accuracy: 0.5929
# Epoch 22/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9185 - accuracy: 0.5714 - val_loss: 0.9066 - val_accuracy: 0.5947
# Epoch 23/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9143 - accuracy: 0.5747 - val_loss: 0.9032 - val_accuracy: 0.5947
# Epoch 24/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9104 - accuracy: 0.5747 - val_loss: 0.9000 - val_accuracy: 0.5947
# Epoch 25/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9068 - accuracy: 0.5747 - val_loss: 0.8969 - val_accuracy: 0.5944
# Epoch 26/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9031 - accuracy: 0.5747 - val_loss: 0.8938 - val_accuracy: 0.5941
# Epoch 27/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8994 - accuracy: 0.5749 - val_loss: 0.8905 - val_accuracy: 0.5970
# Epoch 28/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8956 - accuracy: 0.5768 - val_loss: 0.8871 - val_accuracy: 0.5970
# Epoch 29/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8917 - accuracy: 0.5768 - val_loss: 0.8837 - val_accuracy: 0.5967
# Epoch 30/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8878 - accuracy: 0.5768 - val_loss: 0.8803 - val_accuracy: 0.6079
# Epoch 31/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8839 - accuracy: 0.5904 - val_loss: 0.8771 - val_accuracy: 0.6082
# Epoch 32/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8802 - accuracy: 0.5905 - val_loss: 0.8740 - val_accuracy: 0.6082
# Epoch 33/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8766 - accuracy: 0.5905 - val_loss: 0.8712 - val_accuracy: 0.6085
# Epoch 34/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8734 - accuracy: 0.5902 - val_loss: 0.8685 - val_accuracy: 0.6085
# Epoch 35/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8704 - accuracy: 0.5904 - val_loss: 0.8661 - val_accuracy: 0.6085
# Epoch 36/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8678 - accuracy: 0.5910 - val_loss: 0.8638 - val_accuracy: 0.6073
# Epoch 37/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8655 - accuracy: 0.5896 - val_loss: 0.8617 - val_accuracy: 0.6079
# Epoch 38/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8635 - accuracy: 0.5929 - val_loss: 0.8598 - val_accuracy: 0.6079
# Epoch 39/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8619 - accuracy: 0.5926 - val_loss: 0.8582 - val_accuracy: 0.6079
# Epoch 40/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8605 - accuracy: 0.5926 - val_loss: 0.8568 - val_accuracy: 0.6079
# Epoch 41/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8593 - accuracy: 0.5928 - val_loss: 0.8557 - val_accuracy: 0.6052
# Epoch 42/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8584 - accuracy: 0.5947 - val_loss: 0.8549 - val_accuracy: 0.6049
# Epoch 43/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.8577 - accuracy: 0.5978 - val_loss: 0.8542 - val_accuracy: 0.6058
# Epoch 44/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8570 - accuracy: 0.6029 - val_loss: 0.8537 - val_accuracy: 0.6058
# Epoch 45/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8563 - accuracy: 0.6027 - val_loss: 0.8533 - val_accuracy: 0.6058
# Epoch 46/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8557 - accuracy: 0.6027 - val_loss: 0.8530 - val_accuracy: 0.6058
# Epoch 47/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8551 - accuracy: 0.6027 - val_loss: 0.8529 - val_accuracy: 0.6058
# Epoch 48/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8545 - accuracy: 0.6027 - val_loss: 0.8528 - val_accuracy: 0.6049
# Epoch 49/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8539 - accuracy: 0.6064 - val_loss: 0.8529 - val_accuracy: 0.6046
# Epoch 50/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8534 - accuracy: 0.6064 - val_loss: 0.8530 - val_accuracy: 0.6088
# Epoch 51/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8530 - accuracy: 0.6095 - val_loss: 0.8531 - val_accuracy: 0.6091
# Epoch 52/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8527 - accuracy: 0.6094 - val_loss: 0.8531 - val_accuracy: 0.6096
# The cross-entropy on the test data of the tensor flow ANN is 0.853

# %%
#plt.plot((history.history['loss']))
plt.plot(history.history['loss'],     color = 'blue', label = 'train')
plt.plot(history.history['val_loss'], color = 'red', label = 'test')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

# %% [markdown]
# <font color='red'>
#
# **ANSWER Q4** <br>

# %% [markdown]
# The cross-entropy on the test data is around 0.843 (changes ofcourse). The Epoch vs Loss has been plotted in the above graph. This model predicts better as the cross entropy is lesser than discreet choice model, which means better accuracy

# %% [markdown]
# ### Q5. Compute the WtP of the average decision maker to reduce the share of foreigners in a neighbourhood by 1 percentage point using the results from the hybrid model. Compare the outcome with the results of your discrete choice model (0.5 pts)

# %%
beta_store = np.squeeze((betas[0][0]))
beta_foreign = np.squeeze((betas[0][1]))
print('Beta_foreign    = ', "{:.3f}".format(beta_foreign )) 
print('Beta_store = ', "{:.3f}".format(beta_store ))
WtP_storage = beta_store/beta_foreign
print('WtP estimate  = ', "{:.2f}".format(WtP_storage),' minutes per less percentage of foreigners')
# Out:
# Beta_foreign    =  0.108
# Beta_store =  -1.392
# WtP estimate  =  -12.88  minutes per less percentage of foreigners

# %% [markdown]
# <font color='red'>
#
# **ANSWER Q5** <br>

# %% [markdown]
# Compared to he discrete choice model (WtP = 0.03), the willingnes to pay estimate given by the hybrid model (WtP = 0.06) is higher.

# %% [markdown]
# ### Q6. Explore whether, or not, the preferences of the inhabitants of the four cities regarding the trade-off between share of foreigners and distance to grocery stores are equal across the four cities. (1.5 pts)
#
# Perform a series of (clever) analyses, and interpret the findings. In other words, can we conclude that the inhabintants of all cities are equally xenophobic? For these analysis, use hybrid models, and/or DCMs.
#
# **Hint:** create new features capturing for the share of foreigners *per city*.

# %%
# create a dataframe for each city and execute it for each city:

###### Mainz, Germany

# Define the features and the output class
X = df[['STORES1','TRANSPORT1','CITY1','NOISE1','GREEN1','FOREIGN1','STORES2','TRANSPORT2','CITY2','NOISE2','GREEN2','FOREIGN2','STORES3','TRANSPORT3','CITY3','NOISE3','GREEN3','FOREIGN3','SSTADT',	'RESPCITY',	'WOMAN',	'AGE']]
X = X[X['RESPCITY'] == 1]

# Define the output target
Y = df['CHOICE']
Y = Y[citylist1]
Y_cat = to_categorical(Y-1, num_classes = 3)

# Create x input for MNL layer, and rescale
scale = 100 # We cannot just use the sklearn scaler here, as it is import for the interpretation later how the input data are scaled. 

x_mnl = np.array([[np.divide(X['STORES1'], scale), np.divide(X['FOREIGN1'], scale)],
                  [np.divide(X['STORES2'], scale), np.divide(X['FOREIGN2'], scale)],
                  [np.divide(X['STORES3'], scale), np.divide(X['FOREIGN3'], scale)]])
x_mnl = np.swapaxes(x_mnl, 0, 2)
x_mnl = np.expand_dims(x_mnl, 3)
print('Shape of x_mnl', x_mnl.shape)

# Create x input for ANN layer
x_ann = np.array([[ X['CITY1'],X['TRANSPORT1'], X['NOISE1'], X['GREEN1'],X['TRANSPORT2'], X['CITY2'],X['TRANSPORT2'], X['NOISE2'], X['GREEN2'], X['TRANSPORT3'], X['CITY3'],X['TRANSPORT3'], X['NOISE3'], X['GREEN3'], X['SSTADT'], X['WOMAN'],X['RESPCITY'], X['AGE']]])
x_ann = np.squeeze(np.swapaxes(x_ann, 0, 2))

# Rescale input for the ANN part
scaler = StandardScaler()  
scaler.fit(x_ann)  
x_ann = scaler.transform(x_ann)  
print('Shape of x_ann',x_ann.shape)

# Split the data into a training and test part
X_mnl_train, X_mnl_test, Y_train, Y_test = train_test_split(x_mnl, Y_cat, random_state = 1, test_size = 0.35)
X_ann_train, X_ann_test, Y_train, Y_test = train_test_split(x_ann, Y_cat, random_state = 1, test_size = 0.35)
print('Total number of obervations in the data set = ', len(x_mnl))
print('Number of obervations in the training set   = ', len(X_mnl_train))
print('Number of obervations in the test set       = ', len(X_mnl_test))

model.compile(optimizer = Adam(learning_rate = 1e-2), metrics = ["accuracy"], loss = 'categorical_crossentropy')
model.summary()

# Train the model
early_stopping = EarlyStopping(patience = 4, monitor = 'val_loss')
history = model.fit([X_mnl_train, X_ann_train],Y_train, batch_size=len(X_mnl_train), epochs = nEpoch, verbose = 1, validation_data = ([X_mnl_test, X_ann_test], Y_test), callbacks = [early_stopping])

betas_layer = model.get_layer(name = 'MNL_layer')
betas = betas_layer.get_weights()
print('The cross-entropy on the test data of the tensor flow ANN is',"{:.3f}".format(history.history['loss'][-1]))

beta_store = np.squeeze((betas[0][0]))
beta_foreign = np.squeeze((betas[0][1]))
print('Beta_foreign    = ', "{:.3f}".format(beta_foreign )) 
print('Beta_store = ', "{:.3f}".format(beta_store ))
WtP_storage = beta_store/beta_foreign
print('WtP estimate  = ', "{:.2f}".format(WtP_storage),' minutes per less percentage of foreigners')
# Out:
# Shape of x_mnl (2292, 2, 3, 1)
# Shape of x_ann (2292, 18)
# Total number of obervations in the data set =  2292
# Number of obervations in the training set   =  1489
# Number of obervations in the test set       =  803
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Features2ANN (InputLayer)       [(None, 18)]         0
# __________________________________________________________________________________________________
# ANN_layer1 (Dense)              (None, 5)            95          Features2ANN[0][0]
# __________________________________________________________________________________________________
# Features2MNL (InputLayer)       [(None, 2, 3, 1)]    0
# __________________________________________________________________________________________________
# ANN_layer2 (Dense)              (None, 5)            30          ANN_layer1[0][0]
# __________________________________________________________________________________________________
# MNL_layer (Conv2D)              (None, 1, 3, 1)      2           Features2MNL[0][0]
# __________________________________________________________________________________________________
# V_ANN (Dense)                   (None, 3)            18          ANN_layer2[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_MNL (Reshape)       (None, 3)            0           MNL_layer[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_ANN (Reshape)       (None, 3)            0           V_ANN[0][0]
# __________________________________________________________________________________________________
# Combining_Vs (Add)              (None, 3)            0           Flatten_Dim_MNL[0][0]
#                                                                  Flatten_Dim_ANN[0][0]
# __________________________________________________________________________________________________
# Probability (Activation)        (None, 3)            0           Combining_Vs[0][0]
# ==================================================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 1s 545ms/step - loss: 0.8687 - accuracy: 0.5977 - val_loss: 0.8613 - val_accuracy: 0.6152
# Epoch 2/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8586 - accuracy: 0.6004 - val_loss: 0.8588 - val_accuracy: 0.5965
# Epoch 3/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8531 - accuracy: 0.5809 - val_loss: 0.8587 - val_accuracy: 0.5953
# Epoch 4/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8508 - accuracy: 0.5809 - val_loss: 0.8601 - val_accuracy: 0.6002
# Epoch 5/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8501 - accuracy: 0.5910 - val_loss: 0.8624 - val_accuracy: 0.6202
# Epoch 6/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8503 - accuracy: 0.5977 - val_loss: 0.8652 - val_accuracy: 0.6202
# Epoch 7/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8509 - accuracy: 0.5977 - val_loss: 0.8677 - val_accuracy: 0.6052
# The cross-entropy on the test data of the tensor flow ANN is 0.851
# Beta_foreign    =  -0.149
# Beta_store =  -1.651
# WtP estimate  =  11.08  minutes per less percentage of foreigners

# %%
# create a dataframe for each city and execute it for each city:

###### Hannover, Germany

# Define the features and the output class
X = df[['STORES1','TRANSPORT1','CITY1','NOISE1','GREEN1','FOREIGN1','STORES2','TRANSPORT2','CITY2','NOISE2','GREEN2','FOREIGN2','STORES3','TRANSPORT3','CITY3','NOISE3','GREEN3','FOREIGN3','SSTADT',	'RESPCITY',	'WOMAN',	'AGE']]
X = X[X['RESPCITY'] == 2]

# Define the output target
Y = df['CHOICE']
Y = Y[citylist2]
Y_cat = to_categorical(Y-1, num_classes = 3)

# Create x input for MNL layer, and rescale
scale = 100 # We cannot just use the sklearn scaler here, as it is import for the interpretation later how the input data are scaled. 

x_mnl = np.array([[np.divide(X['STORES1'], scale), np.divide(X['FOREIGN1'], scale)],
                  [np.divide(X['STORES2'], scale), np.divide(X['FOREIGN2'], scale)],
                  [np.divide(X['STORES3'], scale), np.divide(X['FOREIGN3'], scale)]])
x_mnl = np.swapaxes(x_mnl, 0, 2)
x_mnl = np.expand_dims(x_mnl, 3)
print('Shape of x_mnl', x_mnl.shape)

# Create x input for ANN layer
x_ann = np.array([[ X['CITY1'],X['TRANSPORT1'], X['NOISE1'], X['GREEN1'],X['TRANSPORT2'], X['CITY2'],X['TRANSPORT2'], X['NOISE2'], X['GREEN2'], X['TRANSPORT3'], X['CITY3'],X['TRANSPORT3'], X['NOISE3'], X['GREEN3'], X['SSTADT'], X['WOMAN'],X['RESPCITY'], X['AGE']]])
x_ann = np.squeeze(np.swapaxes(x_ann, 0, 2))

# Rescale input for the ANN part
scaler = StandardScaler()  
scaler.fit(x_ann)  
x_ann = scaler.transform(x_ann)  
print('Shape of x_ann',x_ann.shape)

# Split the data into a training and test part
X_mnl_train, X_mnl_test, Y_train, Y_test = train_test_split(x_mnl, Y_cat, random_state = 1, test_size = 0.35)
X_ann_train, X_ann_test, Y_train, Y_test = train_test_split(x_ann, Y_cat, random_state = 1, test_size = 0.35)
print('Total number of obervations in the data set = ', len(x_mnl))
print('Number of obervations in the training set   = ', len(X_mnl_train))
print('Number of obervations in the test set       = ', len(X_mnl_test))

model.compile(optimizer = Adam(learning_rate = 1e-2), metrics = ["accuracy"], loss = 'categorical_crossentropy')
model.summary()

# Train the model
early_stopping = EarlyStopping(patience = 4, monitor = 'val_loss')
history = model.fit([X_mnl_train, X_ann_train],Y_train, batch_size=len(X_mnl_train), epochs = nEpoch, verbose = 1, validation_data = ([X_mnl_test, X_ann_test], Y_test), callbacks = [early_stopping])

betas_layer = model.get_layer(name = 'MNL_layer')
betas = betas_layer.get_weights()
print('The cross-entropy on the test data of the tensor flow ANN is',"{:.3f}".format(history.history['loss'][-1]))

beta_store = np.squeeze((betas[0][0]))
beta_foreign = np.squeeze((betas[0][1]))
print('Beta_foreign    = ', "{:.3f}".format(beta_foreign )) 
print('Beta_store = ', "{:.3f}".format(beta_store ))
WtP_storage = beta_store/beta_foreign
print('WtP estimate  = ', "{:.2f}".format(WtP_storage),' minutes per less percentage of foreigners')
# Out:
# Shape of x_mnl (1724, 2, 3, 1)
# Shape of x_ann (1724, 18)
# Total number of obervations in the data set =  1724
# Number of obervations in the training set   =  1120
# Number of obervations in the test set       =  604
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Features2ANN (InputLayer)       [(None, 18)]         0
# __________________________________________________________________________________________________
# ANN_layer1 (Dense)              (None, 5)            95          Features2ANN[0][0]
# __________________________________________________________________________________________________
# Features2MNL (InputLayer)       [(None, 2, 3, 1)]    0
# __________________________________________________________________________________________________
# ANN_layer2 (Dense)              (None, 5)            30          ANN_layer1[0][0]
# __________________________________________________________________________________________________
# MNL_layer (Conv2D)              (None, 1, 3, 1)      2           Features2MNL[0][0]
# __________________________________________________________________________________________________
# V_ANN (Dense)                   (None, 3)            18          ANN_layer2[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_MNL (Reshape)       (None, 3)            0           MNL_layer[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_ANN (Reshape)       (None, 3)            0           V_ANN[0][0]
# __________________________________________________________________________________________________
# Combining_Vs (Add)              (None, 3)            0           Flatten_Dim_MNL[0][0]
#                                                                  Flatten_Dim_ANN[0][0]
# __________________________________________________________________________________________________
# Probability (Activation)        (None, 3)            0           Combining_Vs[0][0]
# ==================================================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 459ms/step - loss: 0.8527 - accuracy: 0.5920 - val_loss: 0.8808 - val_accuracy: 0.6026
# Epoch 2/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8409 - accuracy: 0.6241 - val_loss: 0.8808 - val_accuracy: 0.6010
# Epoch 3/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8334 - accuracy: 0.6277 - val_loss: 0.8825 - val_accuracy: 0.6010
# Epoch 4/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.8279 - accuracy: 0.6339 - val_loss: 0.8851 - val_accuracy: 0.5977
# Epoch 5/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8242 - accuracy: 0.6339 - val_loss: 0.8884 - val_accuracy: 0.6109
# Epoch 6/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8224 - accuracy: 0.6455 - val_loss: 0.8919 - val_accuracy: 0.6093
# The cross-entropy on the test data of the tensor flow ANN is 0.822
# Beta_foreign    =  -0.208
# Beta_store =  -1.711
# WtP estimate  =  8.21  minutes per less percentage of foreigners

# %%
# create a dataframe for each city and execute it for each city:

###### Bern, Switzerland

# Define the features and the output class
X = df[['STORES1','TRANSPORT1','CITY1','NOISE1','GREEN1','FOREIGN1','STORES2','TRANSPORT2','CITY2','NOISE2','GREEN2','FOREIGN2','STORES3','TRANSPORT3','CITY3','NOISE3','GREEN3','FOREIGN3','SSTADT',	'RESPCITY',	'WOMAN',	'AGE']]
X = X[X['RESPCITY'] == 3]

# Define the output target
Y = df['CHOICE']
Y = Y[citylist3]
Y_cat = to_categorical(Y-1, num_classes = 3)

# Create x input for MNL layer, and rescale
scale = 100 # We cannot just use the sklearn scaler here, as it is import for the interpretation later how the input data are scaled. 

x_mnl = np.array([[np.divide(X['STORES1'], scale), np.divide(X['FOREIGN1'], scale)],
                  [np.divide(X['STORES2'], scale), np.divide(X['FOREIGN2'], scale)],
                  [np.divide(X['STORES3'], scale), np.divide(X['FOREIGN3'], scale)]])
x_mnl = np.swapaxes(x_mnl, 0, 2)
x_mnl = np.expand_dims(x_mnl, 3)
print('Shape of x_mnl', x_mnl.shape)

# Create x input for ANN layer
x_ann = np.array([[ X['CITY1'],X['TRANSPORT1'], X['NOISE1'], X['GREEN1'],X['TRANSPORT2'], X['CITY2'],X['TRANSPORT2'], X['NOISE2'], X['GREEN2'], X['TRANSPORT3'], X['CITY3'],X['TRANSPORT3'], X['NOISE3'], X['GREEN3'], X['SSTADT'], X['WOMAN'],X['RESPCITY'], X['AGE']]])
x_ann = np.squeeze(np.swapaxes(x_ann, 0, 2))

# Rescale input for the ANN part
scaler = StandardScaler()  
scaler.fit(x_ann)  
x_ann = scaler.transform(x_ann)  
print('Shape of x_ann',x_ann.shape)

# Split the data into a training and test part
X_mnl_train, X_mnl_test, Y_train, Y_test = train_test_split(x_mnl, Y_cat, random_state = 1, test_size = 0.35)
X_ann_train, X_ann_test, Y_train, Y_test = train_test_split(x_ann, Y_cat, random_state = 1, test_size = 0.35)
print('Total number of obervations in the data set = ', len(x_mnl))
print('Number of obervations in the training set   = ', len(X_mnl_train))
print('Number of obervations in the test set       = ', len(X_mnl_test))

model.compile(optimizer = Adam(learning_rate = 1e-2), metrics = ["accuracy"], loss = 'categorical_crossentropy')
model.summary()

# Train the model
early_stopping = EarlyStopping(patience = 4, monitor = 'val_loss')
history = model.fit([X_mnl_train, X_ann_train],Y_train, batch_size=len(X_mnl_train), epochs = nEpoch, verbose = 1, validation_data = ([X_mnl_test, X_ann_test], Y_test), callbacks = [early_stopping])

betas_layer = model.get_layer(name = 'MNL_layer')
betas = betas_layer.get_weights()
print('The cross-entropy on the test data of the tensor flow ANN is',"{:.3f}".format(history.history['loss'][-1]))

beta_store = np.squeeze((betas[0][0]))
beta_foreign = np.squeeze((betas[0][1]))
print('Beta_foreign    = ', "{:.3f}".format(beta_foreign )) 
print('Beta_store = ', "{:.3f}".format(beta_store ))
WtP_storage = beta_store/beta_foreign
print('WtP estimate  = ', "{:.2f}".format(WtP_storage),' minutes per less percentage of foreigners')
# Out:
# Shape of x_mnl (3160, 2, 3, 1)
# Shape of x_ann (3160, 18)
# Total number of obervations in the data set =  3160
# Number of obervations in the training set   =  2054
# Number of obervations in the test set       =  1106
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Features2ANN (InputLayer)       [(None, 18)]         0
# __________________________________________________________________________________________________
# ANN_layer1 (Dense)              (None, 5)            95          Features2ANN[0][0]
# __________________________________________________________________________________________________
# Features2MNL (InputLayer)       [(None, 2, 3, 1)]    0
# __________________________________________________________________________________________________
# ANN_layer2 (Dense)              (None, 5)            30          ANN_layer1[0][0]
# __________________________________________________________________________________________________
# MNL_layer (Conv2D)              (None, 1, 3, 1)      2           Features2MNL[0][0]
# __________________________________________________________________________________________________
# V_ANN (Dense)                   (None, 3)            18          ANN_layer2[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_MNL (Reshape)       (None, 3)            0           MNL_layer[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_ANN (Reshape)       (None, 3)            0           V_ANN[0][0]
# __________________________________________________________________________________________________
# Combining_Vs (Add)              (None, 3)            0           Flatten_Dim_MNL[0][0]
#                                                                  Flatten_Dim_ANN[0][0]
# __________________________________________________________________________________________________
# Probability (Activation)        (None, 3)            0           Combining_Vs[0][0]
# ==================================================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 443ms/step - loss: 0.8787 - accuracy: 0.6008 - val_loss: 0.8664 - val_accuracy: 0.5832
# Epoch 2/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.8586 - accuracy: 0.6071 - val_loss: 0.8548 - val_accuracy: 0.5850
# Epoch 3/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8454 - accuracy: 0.6066 - val_loss: 0.8482 - val_accuracy: 0.5895
# Epoch 4/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8374 - accuracy: 0.6120 - val_loss: 0.8446 - val_accuracy: 0.5913
# Epoch 5/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8329 - accuracy: 0.6120 - val_loss: 0.8429 - val_accuracy: 0.5895
# Epoch 6/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8307 - accuracy: 0.6018 - val_loss: 0.8420 - val_accuracy: 0.5986
# Epoch 7/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8296 - accuracy: 0.6159 - val_loss: 0.8415 - val_accuracy: 0.6076
# Epoch 8/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8290 - accuracy: 0.6256 - val_loss: 0.8409 - val_accuracy: 0.6076
# Epoch 9/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8284 - accuracy: 0.6261 - val_loss: 0.8403 - val_accuracy: 0.6067
# Epoch 10/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8275 - accuracy: 0.6285 - val_loss: 0.8396 - val_accuracy: 0.6103
# Epoch 11/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8266 - accuracy: 0.6295 - val_loss: 0.8390 - val_accuracy: 0.6103
# Epoch 12/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8257 - accuracy: 0.6295 - val_loss: 0.8385 - val_accuracy: 0.6103
# Epoch 13/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8250 - accuracy: 0.6295 - val_loss: 0.8380 - val_accuracy: 0.6103
# Epoch 14/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8245 - accuracy: 0.6295 - val_loss: 0.8376 - val_accuracy: 0.6103
# Epoch 15/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8243 - accuracy: 0.6295 - val_loss: 0.8372 - val_accuracy: 0.6130
# Epoch 16/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8241 - accuracy: 0.6295 - val_loss: 0.8368 - val_accuracy: 0.6130
# Epoch 17/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8240 - accuracy: 0.6295 - val_loss: 0.8365 - val_accuracy: 0.6203
# Epoch 18/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8238 - accuracy: 0.6344 - val_loss: 0.8361 - val_accuracy: 0.6203
# Epoch 19/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8236 - accuracy: 0.6344 - val_loss: 0.8358 - val_accuracy: 0.6203
# Epoch 20/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8232 - accuracy: 0.6349 - val_loss: 0.8355 - val_accuracy: 0.6203
# Epoch 21/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8228 - accuracy: 0.6349 - val_loss: 0.8352 - val_accuracy: 0.6203
# Epoch 22/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8223 - accuracy: 0.6349 - val_loss: 0.8349 - val_accuracy: 0.6203
# Epoch 23/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8218 - accuracy: 0.6349 - val_loss: 0.8347 - val_accuracy: 0.6203
# Epoch 24/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8213 - accuracy: 0.6349 - val_loss: 0.8344 - val_accuracy: 0.6203
# Epoch 25/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8210 - accuracy: 0.6344 - val_loss: 0.8342 - val_accuracy: 0.6203
# Epoch 26/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8207 - accuracy: 0.6344 - val_loss: 0.8341 - val_accuracy: 0.6203
# Epoch 27/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8205 - accuracy: 0.6344 - val_loss: 0.8340 - val_accuracy: 0.6203
# Epoch 28/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8204 - accuracy: 0.6344 - val_loss: 0.8339 - val_accuracy: 0.6203
# Epoch 29/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8203 - accuracy: 0.6344 - val_loss: 0.8339 - val_accuracy: 0.6130
# Epoch 30/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8202 - accuracy: 0.6295 - val_loss: 0.8339 - val_accuracy: 0.6130
# Epoch 31/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8202 - accuracy: 0.6295 - val_loss: 0.8340 - val_accuracy: 0.6130
# Epoch 32/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8201 - accuracy: 0.6295 - val_loss: 0.8341 - val_accuracy: 0.6130
# Epoch 33/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8201 - accuracy: 0.6295 - val_loss: 0.8342 - val_accuracy: 0.6130
# The cross-entropy on the test data of the tensor flow ANN is 0.820
# Beta_foreign    =  -0.541
# Beta_store =  -2.046
# WtP estimate  =  3.78  minutes per less percentage of foreigners

# %%
# create a dataframe for each city and execute it for each city:

###### Zurich, Switzerland

# Define the features and the output class
X = df[['STORES1','TRANSPORT1','CITY1','NOISE1','GREEN1','FOREIGN1','STORES2','TRANSPORT2','CITY2','NOISE2','GREEN2','FOREIGN2','STORES3','TRANSPORT3','CITY3','NOISE3','GREEN3','FOREIGN3','SSTADT',	'RESPCITY',	'WOMAN',	'AGE']]
X = X[X['RESPCITY'] == 4]

# Define the output target
Y = df['CHOICE']
Y = Y[citylist4]
Y_cat = to_categorical(Y-1, num_classes = 3)

# Create x input for MNL layer, and rescale
scale = 100 # We cannot just use the sklearn scaler here, as it is import for the interpretation later how the input data are scaled. 

x_mnl = np.array([[np.divide(X['STORES1'], scale), np.divide(X['FOREIGN1'], scale)],
                  [np.divide(X['STORES2'], scale), np.divide(X['FOREIGN2'], scale)],
                  [np.divide(X['STORES3'], scale), np.divide(X['FOREIGN3'], scale)]])
x_mnl = np.swapaxes(x_mnl, 0, 2)
x_mnl = np.expand_dims(x_mnl, 3)
print('Shape of x_mnl', x_mnl.shape)

# Create x input for ANN layer
x_ann = np.array([[ X['CITY1'],X['TRANSPORT1'], X['NOISE1'], X['GREEN1'],X['TRANSPORT2'], X['CITY2'],X['TRANSPORT2'], X['NOISE2'], X['GREEN2'], X['TRANSPORT3'], X['CITY3'],X['TRANSPORT3'], X['NOISE3'], X['GREEN3'], X['SSTADT'], X['WOMAN'],X['RESPCITY'], X['AGE']]])
x_ann = np.squeeze(np.swapaxes(x_ann, 0, 2))

# Rescale input for the ANN part
scaler = StandardScaler()  
scaler.fit(x_ann)  
x_ann = scaler.transform(x_ann)  
print('Shape of x_ann',x_ann.shape)

# Split the data into a training and test part
X_mnl_train, X_mnl_test, Y_train, Y_test = train_test_split(x_mnl, Y_cat, random_state = 1, test_size = 0.35)
X_ann_train, X_ann_test, Y_train, Y_test = train_test_split(x_ann, Y_cat, random_state = 1, test_size = 0.35)
print('Total number of obervations in the data set = ', len(x_mnl))
print('Number of obervations in the training set   = ', len(X_mnl_train))
print('Number of obervations in the test set       = ', len(X_mnl_test))

model.compile(optimizer = Adam(learning_rate = 1e-2), metrics = ["accuracy"], loss = 'categorical_crossentropy')
model.summary()

# Train the model
early_stopping = EarlyStopping(patience = 4, monitor = 'val_loss')
history = model.fit([X_mnl_train, X_ann_train],Y_train, batch_size=len(X_mnl_train), epochs = nEpoch, verbose = 1, validation_data = ([X_mnl_test, X_ann_test], Y_test), callbacks = [early_stopping])

betas_layer = model.get_layer(name = 'MNL_layer')
betas = betas_layer.get_weights()
print('The cross-entropy on the test data of the tensor flow ANN is',"{:.3f}".format(history.history['loss'][-1]))

beta_store = np.squeeze((betas[0][0]))
beta_foreign = np.squeeze((betas[0][1]))
print('Beta_foreign    = ', "{:.3f}".format(beta_foreign )) 
print('Beta_store = ', "{:.3f}".format(beta_store ))
WtP_storage = beta_store/beta_foreign
print('WtP estimate  = ', "{:.2f}".format(WtP_storage),' minutes per less percentage of foreigners')
# Out:
# Shape of x_mnl (2544, 2, 3, 1)
# Shape of x_ann (2544, 18)
# Total number of obervations in the data set =  2544
# Number of obervations in the training set   =  1653
# Number of obervations in the test set       =  891
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Features2ANN (InputLayer)       [(None, 18)]         0
# __________________________________________________________________________________________________
# ANN_layer1 (Dense)              (None, 5)            95          Features2ANN[0][0]
# __________________________________________________________________________________________________
# Features2MNL (InputLayer)       [(None, 2, 3, 1)]    0
# __________________________________________________________________________________________________
# ANN_layer2 (Dense)              (None, 5)            30          ANN_layer1[0][0]
# __________________________________________________________________________________________________
# MNL_layer (Conv2D)              (None, 1, 3, 1)      2           Features2MNL[0][0]
# __________________________________________________________________________________________________
# V_ANN (Dense)                   (None, 3)            18          ANN_layer2[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_MNL (Reshape)       (None, 3)            0           MNL_layer[0][0]
# __________________________________________________________________________________________________
# Flatten_Dim_ANN (Reshape)       (None, 3)            0           V_ANN[0][0]
# __________________________________________________________________________________________________
# Combining_Vs (Add)              (None, 3)            0           Flatten_Dim_MNL[0][0]
#                                                                  Flatten_Dim_ANN[0][0]
# __________________________________________________________________________________________________
# Probability (Activation)        (None, 3)            0           Combining_Vs[0][0]
# ==================================================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 442ms/step - loss: 0.8395 - accuracy: 0.6207 - val_loss: 0.8693 - val_accuracy: 0.5993
# Epoch 2/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8334 - accuracy: 0.6213 - val_loss: 0.8656 - val_accuracy: 0.6004
# Epoch 3/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8302 - accuracy: 0.6213 - val_loss: 0.8654 - val_accuracy: 0.6004
# Epoch 4/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8285 - accuracy: 0.6213 - val_loss: 0.8667 - val_accuracy: 0.5948
# Epoch 5/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8274 - accuracy: 0.6219 - val_loss: 0.8684 - val_accuracy: 0.5903
# Epoch 6/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8266 - accuracy: 0.6183 - val_loss: 0.8697 - val_accuracy: 0.5892
# Epoch 7/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8259 - accuracy: 0.6183 - val_loss: 0.8706 - val_accuracy: 0.5892
# The cross-entropy on the test data of the tensor flow ANN is 0.826
# Beta_foreign    =  -0.609
# Beta_store =  -2.116
# WtP estimate  =  3.48  minutes per less percentage of foreigners

# %% [markdown]
# <font color='red'>
#
# **ANSWER Q6** <br>

# %% [markdown]
# The findings of Q6 summarized:
# 1. Mainz: <br>
# Beta_foreign    =  -0.149<br>
# Beta_store =  -1.651<br>
# WtP estimate  =  11.08  minutes per less percentage of foreigners<br>
# <br>
# 2. Hannover: <br>
# Beta_foreign    =  -0.208<br>
# Beta_store =  -1.711<br>
# WtP estimate  =  8.21  minutes per less percentage of foreigners<br>
# <br>
# 3. Bern:<br>
# Beta_foreign    =  -0.541<br>
# Beta_store =  -2.046<br>
# WtP estimate  =  3.78  minutes per less percentage of foreigners<br>
# <br>
# 4. Zurich:<br>
# Beta_foreign    =  -0.609<br>
# Beta_store =  -2.116<br>
# WtP estimate  =  3.48  minutes per less percentage of foreigners<br>
# <br>

# %% [markdown]
# By looking at the values for the betas for foreigners, the conclusion can be drawn that the German cities are less xenophoic then the Swiss cities. The more negative the value for beta foreign, the less attractive a increase in percentage of foreigners is. Besides that the beta for the distance to the store is also more negative for the Swiss cities in comparison to the German cities. The order from less to more xenophobic: Mains, Hannover, Bern, Zurich.By looking at the willingness to pay estimate a similar conclusion can be drawn. However  the beta_store has influence as well the order remains the same.
#
# For the best estimation we would suggest to look more to the beta value of foreign, since the distance to store is not related to xenophobia.
